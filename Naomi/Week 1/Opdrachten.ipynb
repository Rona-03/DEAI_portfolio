# %% [markdown]
# # Werkcollege-opdrachten Week 1.1

# %% [markdown]
# ## Maak een virtual environment

# %% [markdown]
# Zorg dat je met behulp van de handleiding *Bouw en gebruik van virtual environments - Handleiding* een virtual environment hebt gemaakt, dat jou en je duopartner garandeert altijd dezelfde versie van geïmporteerde dependencies te gebruiken.<br>
# Voeg hier vervolgens de pandas- en de sqlite3-dependency aan toe.<br>
# Als je dit allemaal goed hebt gedaan moet de onderstaande code bij jullie allebei succesvol runnen:

# %%
import pandas as pd
import sqlite3
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# N.B.: de 2 reeds geschreven coderegels zorgen ervoor dat eventuele warnings, die code-outputs lelijker maken, uitgezet worden.

# %% [markdown]
# Zorg er daarnaast voor dat je...
# - Het bestand Waarheidstabel.png in dezelfde map als dit notebook hebt staan.
# - Het bestand Prinstabel.png in dezelfde map als dit notebook hebt staan.
# - Alle informatie onder het kopje *Basisoperaties* van de cheatsheet *Van Java naar Python - Cheatsheet* bij de hand hebt.

# %% [markdown]
# ## Output, variabelen en input

# %% [markdown]
# Geef code waarmee het volgende op het scherm komt te staan:<br>
# geef me je geld <br>
# of ik gebruik geweld, <br>
# toen kwam de controle aangesneld

# %%
print("geef me je geld\nof ik gebruik geweld,\ntoen kwam de controle aangesneld")
# Out:
# geef me je geld
# of ik gebruik geweld,
# toen kwam de controle aangesneld

# %% [markdown]
# Declareer 2 variabelen zodat de volgende tekst geprint wordt:<br>
# Apenhoofd<br>
# Paardenstaart

# %%
woord1 = "Apenhoofd"
woord2 = "Paardenstaart"

print(woord1)
print(woord2)
# Out:
# Apenhoofd
# Paardenstaart

# %% [markdown]
# Voeg code toe zodat het programma het volgende doet:<br>
# 1): Op het scherm komt A, B, C, D, ..., F, G te staan<br>
# 2): De gebruiker voert een letter in<br>
# 3): Op het scherm komt te staan:<br>
# Het is inderdaad:<br>
# *ingevoerde letter*

# %%
print("A, B, C, D, ..., F, G")

Antwoord = input("Welke letter moet er op de ... staan?: ")

print(f"Het is inderdaad:\n{Antwoord}")
# maar je kan het ook op twee aparte prints zetten
# Out:
# A, B, C, D, ..., F, G
# Het is inderdaad:
# e

# %% [markdown]
# ## Stringconcatenatie en Rekenen

# %% [markdown]
# Schrijf code dat een inkomen inleest en het volgende uitprint:<br>
# Uw inkomen (*ingelezen inkomen*) is zeer acceptabel.

# %%
inkomen = input("Wat is je inkomen?")
print(f"Uw inkomen {inkomen} is zeer acceptabel.")
# Out:
# Uw inkomen 30 is zeer acceptabel.

# %% [markdown]
# De oppervlakte van een driehoek is 1/2 * hoogte * basis<br>
# Schrijf code zodat het programma het volgende doet:<br>
# 1): Op het scherm komt Wat is de basis? te staan<br>
# 2): De gebruiker voert een basis in<br>
# 3): Op het scherm komt Wat is de hoogte? te staan<br>
# 4): De gebruiker voert een hoogte in<br>
# 5): Op het scherm komt: De oppervlakte van de driehoek is *berekende oppervlakte* te staan

# %%
# Eerst vraag je input daarna zet je de input om naar een float 
# Anders krijg je een error bij het berekenen dat het een float moet zijn
basis_input = input("Wat is de basis?")
basis = float(basis_input)

hoogte_input = input("Wat is de hoogte?")
hoogte = float(hoogte_input)

berekende_opervlakte = (1/2)*hoogte*basis

print(f"De oppervlakte van de driehoek is {berekende_opervlakte} te staan")
# Out:
# De oppervlakte van de driehoek is 30.0 te staan

# %% [markdown]
# ## if() en booleans

# %% [markdown]
# Schrijf code dat het volgende doet:<br>
# 1): De gebruiker voert in hoe oud iemand is<br>
# 2): De gebruiker voert in of de ouders meegekomen zijn (input is J of N)<br><br>
#
# Als...
# - Jonger dan 6, wel ouders: op het scherm staat Je mag het zwembad in
# - Jonger dan 6, geen ouders: op het scherm staat Je mag het niet zwembad in
# - Leeftijd vanaf 6, geen ouders: op het scherm staat Je mag het zwembad in als je een diploma hebt
# - Leeftijd vanaf 6, wel ouders: op het scherm staat Waarom neem je nog je ouders mee?

# %%
# zet leeftijd naar een int
leeftijd = int(input("Leeftijd?"))
# veranderd een j/n naar een J/N automaties
ouders= input("Ouders zijn mee? J/N").upper()

if(leeftijd < 6):
    if(ouders == "J"):
        print("Je mag het zwembad in")
    else:
        print("Je mag niet het zwembad in")
elif(leeftijd >= 6):
    if(ouders == "J"):
        print("Waarom neem je nog je ouders mee?")
    else:
        print("Je mag het zwambad in als je een diploma hebt")
# Out:
# Waarom neem je nog je ouders mee?

# %% [markdown]
# Schrijf code zodat de boolean-variabelen een en twee aangemaakt worden en waarmee de juiste waarde in de boolean-variabele uitkomst komt te staan. In de waarheidstabel hieronder staat wat de waarde van uitkomst is bij de verschillende mogelijke combinaties van een en twee.<br><br>
# <img src="Waarheidstabel.png">

# %%
# een = True
# twee = True
# uitkomst = not een or twee

# Lijst met twee boolean waarden
waarden = [True, False]
# Opmaak (zodat je weet welke true/false onder een en twee vallen) + schijdings lijn
print(f"{'een':<6} {'twee':<6} {'uitkomst':<8}")
print("-" * 22)

# Hier zeg je: neem elke waarden uit de lijst en stop hem in een
for een in waarden:
    # voor elke waarde van een loopt hij door alle waarde van twee
    for twee in waarden:
        uitkomst = not een or twee
        # Opmaak (netjes in de tabel neer te zetten voor verduidelijking)
        print(f"{str(een):<6} {str(twee):<6} {str(uitkomst):<8}")
# Out:
# een    twee   uitkomst
# ----------------------
# True   True   True
# True   False  False
# False  True   True
# False  False  True

# %% [markdown]
# ## Functies

# %% [markdown]
# Schrijf een methode wachtwoord die als parameters twee woorden meekrijgt en het volgende controleert:
# - Als de woorden gelijk zijn, print het programma gelijk.
# - Als de woorden ongelijk zijn print het programma ongelijk.
#
# Vergeet niet dat je de methode niet alleen aan moet maken, maar ook aan moet roepen om output te krijgen.

# %%
def wachtwoord(w1, w2):
    if(w1 == w2):
        print("Gelijk")
    else:
        print("Ongelijk")
    
# Gelijk
wachtwoord(123, 123)
# Ongelijk
wachtwoord(1234, 12)
# Out:
# Gelijk
# Ongelijk

# %% [markdown]
# Schrijf de methode zoekPrins die als parameter een prinses meekrijgt en vervolgens de bijbehorende prins oplevert, volgens de volgende tabel:<br><br>
# <img src="Prinstabel.png"><br>
# Als de naam van de prinses niet in de tabel staat wordt het volgende door de methode teruggegeven: naamloos.<br>
# Roep ten slotte de gemaakte methode ook daadwerkelijk aan met een zelfgekozen prinsessennaam.

# %%
def zoekprins(prinses):
    if(prinses == "Aurora"):
        prins = "Philip"
    elif(prinses == "Ariël"):
        prins = "Eric"
    elif(prinses == "Jasmine"):
        prins = "Aladdin"
    elif(prinses == "Pocahontas"):
        prins = "John"
    elif(prinses == "Belle"):
        prins = "Beast"
    elif(prinses == "Tiana"):
        prins = "Naveen"
    elif(prinses == "Mulan"):
        prins = "Shang"
    else:
        prins = "Naamloos"
    return prins

print(zoekprins("Tiana"))
# Out:
# Naveen

# %% [markdown]
# ## While-loop

# %% [markdown]
# Schrijf de inhoud van de methode wachtwoord. Deze heeft geen parameters en laat de gebruiker twee wachtwoorden invoeren, waarna hij bekijkt of deze gelijk zijn. Zolang dat niet het geval is wordt er eerst Fout, probeer het opnieuw! uitgeprint en moet de gebruiker het opnieuw proberen.<br>Als de gebruiker het goed doet, komt er Succes! op het scherm te staan.

# %%
def wachtwoord2():
    ww1 = input("w1: ")
    ww2 = input("w2: ")

    while(ww1 != ww2):
        print("Fout, probeer het opnieuw!")
        ww2 = input("Opnieuw: ")
    print("Succes!")

wachtwoord2()
# Out:
# Fout, probeer het opnieuw!
# Succes!

# %% [markdown]
# Schrijf de inhoud van de methode tafels. De methode print alle tafels vanaf 1 (dus inclusief de tafel van 1) tot en met de tafel van het meegekregen getal (dus inclusief de tafel van getal).  Zet een witregel tussen alle tafels in. <br>
# Let op:
# - Gebruik een while-loop
# - Gebruik de reeds geschreven methode tafel om een tafel uit te printen

# %%
def tafel(getal: int):
    teller: int = 1

    while(teller <= 10):
        print(f'{teller} x {getal} = {teller * getal}')
        teller += 1

def tafels (getal: int):
    t = 1
    while(t <= getal):
        tafel(t)
        print("")
        t += 1

x: int = int(input())
tafels(x)
# Out:
# 1 x 1 = 1
# 2 x 1 = 2
# 3 x 1 = 3
# 4 x 1 = 4
# 5 x 1 = 5
# 6 x 1 = 6
# 7 x 1 = 7
# 8 x 1 = 8
# 9 x 1 = 9
# 10 x 1 = 10
#
# 1 x 2 = 2
# 2 x 2 = 4
# 3 x 2 = 6
# 4 x 2 = 8
# 5 x 2 = 10
# 6 x 2 = 12
# 7 x 2 = 14
# 8 x 2 = 16
# 9 x 2 = 18
# 10 x 2 = 20
#
# 1 x 3 = 3
# 2 x 3 = 6
# 3 x 3 = 9
# 4 x 3 = 12
# 5 x 3 = 15
# 6 x 3 = 18
# 7 x 3 = 21
# 8 x 3 = 24
# 9 x 3 = 27
# 10 x 3 = 30
#
# 1 x 4 = 4
# 2 x 4 = 8
# 3 x 4 = 12
# 4 x 4 = 16
# 5 x 4 = 20
# 6 x 4 = 24
# 7 x 4 = 28
# 8 x 4 = 32
# 9 x 4 = 36
# 10 x 4 = 40
#
# 1 x 5 = 5
# 2 x 5 = 10
# 3 x 5 = 15
# 4 x 5 = 20
# 5 x 5 = 25
# 6 x 5 = 30
# 7 x 5 = 35
# 8 x 5 = 40
# 9 x 5 = 45
# 10 x 5 = 50
#
# 1 x 6 = 6
# 2 x 6 = 12
# 3 x 6 = 18
# 4 x 6 = 24
# 5 x 6 = 30
# 6 x 6 = 36
# 7 x 6 = 42
# 8 x 6 = 48
# 9 x 6 = 54
# 10 x 6 = 60
#
# 1 x 7 = 7
# 2 x 7 = 14
# 3 x 7 = 21
# 4 x 7 = 28
# 5 x 7 = 35
# 6 x 7 = 42
# 7 x 7 = 49
# 8 x 7 = 56
# 9 x 7 = 63
# 10 x 7 = 70
#
# 1 x 8 = 8
# 2 x 8 = 16
# 3 x 8 = 24
# 4 x 8 = 32
# 5 x 8 = 40
# 6 x 8 = 48
# 7 x 8 = 56
# 8 x 8 = 64
# 9 x 8 = 72
# 10 x 8 = 80
#
# 1 x 9 = 9
# 2 x 9 = 18
# 3 x 9 = 27
# 4 x 9 = 36
# 5 x 9 = 45
# 6 x 9 = 54
# 7 x 9 = 63
# 8 x 9 = 72
# 9 x 9 = 81
# 10 x 9 = 90
#
# 1 x 10 = 10
# 2 x 10 = 20
# 3 x 10 = 30
# 4 x 10 = 40
# 5 x 10 = 50
# 6 x 10 = 60
# 7 x 10 = 70
# 8 x 10 = 80
# 9 x 10 = 90
# 10 x 10 = 100
#
# 1 x 11 = 11
# 2 x 11 = 22
# 3 x 11 = 33
# 4 x 11 = 44
# 5 x 11 = 55
# 6 x 11 = 66
# 7 x 11 = 77
# 8 x 11 = 88
# 9 x 11 = 99
# 10 x 11 = 110
#
# 1 x 12 = 12
# 2 x 12 = 24
# 3 x 12 = 36
# 4 x 12 = 48
# 5 x 12 = 60
# 6 x 12 = 72
# 7 x 12 = 84
# 8 x 12 = 96
# 9 x 12 = 108
# 10 x 12 = 120
#
# 1 x 13 = 13
# 2 x 13 = 26
# 3 x 13 = 39
# 4 x 13 = 52
# 5 x 13 = 65
# 6 x 13 = 78
# 7 x 13 = 91
# 8 x 13 = 104
# 9 x 13 = 117
# 10 x 13 = 130
#
# 1 x 14 = 14
# 2 x 14 = 28
# 3 x 14 = 42
# 4 x 14 = 56
# 5 x 14 = 70
# 6 x 14 = 84
# 7 x 14 = 98
# 8 x 14 = 112
# 9 x 14 = 126
# 10 x 14 = 140
#
# 1 x 15 = 15
# 2 x 15 = 30
# 3 x 15 = 45
# 4 x 15 = 60
# 5 x 15 = 75
# 6 x 15 = 90
# 7 x 15 = 105
# 8 x 15 = 120
# 9 x 15 = 135
# 10 x 15 = 150
#
# 1 x 16 = 16
# 2 x 16 = 32
# 3 x 16 = 48
# 4 x 16 = 64
# 5 x 16 = 80
# 6 x 16 = 96
# 7 x 16 = 112
# 8 x 16 = 128
# 9 x 16 = 144
# 10 x 16 = 160
#
# 1 x 17 = 17
# 2 x 17 = 34
# 3 x 17 = 51
# 4 x 17 = 68
# 5 x 17 = 85
# 6 x 17 = 102
# 7 x 17 = 119
# 8 x 17 = 136
# 9 x 17 = 153
# 10 x 17 = 170
#
# 1 x 18 = 18
# 2 x 18 = 36
# 3 x 18 = 54
# 4 x 18 = 72
# 5 x 18 = 90
# 6 x 18 = 108
# 7 x 18 = 126
# 8 x 18 = 144
# 9 x 18 = 162
# 10 x 18 = 180
#
# 1 x 19 = 19
# 2 x 19 = 38
# 3 x 19 = 57
# 4 x 19 = 76
# 5 x 19 = 95
# 6 x 19 = 114
# 7 x 19 = 133
# 8 x 19 = 152
# 9 x 19 = 171
# 10 x 19 = 190
#
# 1 x 20 = 20
# 2 x 20 = 40
# 3 x 20 = 60
# 4 x 20 = 80
# 5 x 20 = 100
# 6 x 20 = 120
# 7 x 20 = 140
# 8 x 20 = 160
# 9 x 20 = 180
# 10 x 20 = 200
#
# 1 x 21 = 21
# 2 x 21 = 42
# 3 x 21 = 63
# 4 x 21 = 84
# 5 x 21 = 105
# 6 x 21 = 126
# 7 x 21 = 147
# 8 x 21 = 168
# 9 x 21 = 189
# 10 x 21 = 210
#
# 1 x 22 = 22
# 2 x 22 = 44
# 3 x 22 = 66
# 4 x 22 = 88
# 5 x 22 = 110
# 6 x 22 = 132
# 7 x 22 = 154
# 8 x 22 = 176
# 9 x 22 = 198
# 10 x 22 = 220
#
# 1 x 23 = 23
# 2 x 23 = 46
# 3 x 23 = 69
# 4 x 23 = 92
# 5 x 23 = 115
# 6 x 23 = 138
# 7 x 23 = 161
# 8 x 23 = 184
# 9 x 23 = 207
# 10 x 23 = 230
#
# 1 x 24 = 24
# 2 x 24 = 48
# 3 x 24 = 72
# 4 x 24 = 96
# 5 x 24 = 120
# 6 x 24 = 144
# 7 x 24 = 168
# 8 x 24 = 192
# 9 x 24 = 216
# 10 x 24 = 240
#
# 1 x 25 = 25
# 2 x 25 = 50
# 3 x 25 = 75
# 4 x 25 = 100
# 5 x 25 = 125
# 6 x 25 = 150
# 7 x 25 = 175
# 8 x 25 = 200
# 9 x 25 = 225
# 10 x 25 = 250
#
# 1 x 26 = 26
# 2 x 26 = 52
# 3 x 26 = 78
# 4 x 26 = 104
# 5 x 26 = 130
# 6 x 26 = 156
# 7 x 26 = 182
# 8 x 26 = 208
# 9 x 26 = 234
# 10 x 26 = 260
#
# 1 x 27 = 27
# 2 x 27 = 54
# 3 x 27 = 81
# 4 x 27 = 108
# 5 x 27 = 135
# 6 x 27 = 162
# 7 x 27 = 189
# 8 x 27 = 216
# 9 x 27 = 243
# 10 x 27 = 270
#
# 1 x 28 = 28
# 2 x 28 = 56
# 3 x 28 = 84
# 4 x 28 = 112
# 5 x 28 = 140
# 6 x 28 = 168
# 7 x 28 = 196
# 8 x 28 = 224
# 9 x 28 = 252
# 10 x 28 = 280
#
# 1 x 29 = 29
# 2 x 29 = 58
# 3 x 29 = 87
# 4 x 29 = 116
# 5 x 29 = 145
# 6 x 29 = 174
# 7 x 29 = 203
# 8 x 29 = 232
# 9 x 29 = 261
# 10 x 29 = 290
#
# 1 x 30 = 30
# 2 x 30 = 60
# 3 x 30 = 90
# 4 x 30 = 120
# 5 x 30 = 150
# 6 x 30 = 180
# 7 x 30 = 210
# 8 x 30 = 240
# 9 x 30 = 270
# 10 x 30 = 300
#
# 1 x 31 = 31
# 2 x 31 = 62
# 3 x 31 = 93
# 4 x 31 = 124
# 5 x 31 = 155
# 6 x 31 = 186
# 7 x 31 = 217
# 8 x 31 = 248
# 9 x 31 = 279
# 10 x 31 = 310
#
# 1 x 32 = 32
# 2 x 32 = 64
# 3 x 32 = 96
# 4 x 32 = 128
# 5 x 32 = 160
# 6 x 32 = 192
# 7 x 32 = 224
# 8 x 32 = 256
# 9 x 32 = 288
# 10 x 32 = 320
#
# 1 x 33 = 33
# 2 x 33 = 66
# 3 x 33 = 99
# 4 x 33 = 132
# 5 x 33 = 165
# 6 x 33 = 198
# 7 x 33 = 231
# 8 x 33 = 264
# 9 x 33 = 297
# 10 x 33 = 330
#
# 1 x 34 = 34
# 2 x 34 = 68
# 3 x 34 = 102
# 4 x 34 = 136
# 5 x 34 = 170
# 6 x 34 = 204
# 7 x 34 = 238
# 8 x 34 = 272
# 9 x 34 = 306
# 10 x 34 = 340
#
# 1 x 35 = 35
# 2 x 35 = 70
# 3 x 35 = 105
# 4 x 35 = 140
# 5 x 35 = 175
# 6 x 35 = 210
# 7 x 35 = 245
# 8 x 35 = 280
# 9 x 35 = 315
# 10 x 35 = 350
#
# 1 x 36 = 36
# 2 x 36 = 72
# 3 x 36 = 108
# 4 x 36 = 144
# 5 x 36 = 180
# 6 x 36 = 216
# 7 x 36 = 252
# 8 x 36 = 288
# 9 x 36 = 324
# 10 x 36 = 360
#
# 1 x 37 = 37
# 2 x 37 = 74
# 3 x 37 = 111
# 4 x 37 = 148
# 5 x 37 = 185
# 6 x 37 = 222
# 7 x 37 = 259
# 8 x 37 = 296
# 9 x 37 = 333
# 10 x 37 = 370
#
# 1 x 38 = 38
# 2 x 38 = 76
# 3 x 38 = 114
# 4 x 38 = 152
# 5 x 38 = 190
# 6 x 38 = 228
# 7 x 38 = 266
# 8 x 38 = 304
# 9 x 38 = 342
# 10 x 38 = 380
#
# 1 x 39 = 39
# 2 x 39 = 78
# 3 x 39 = 117
# 4 x 39 = 156
# 5 x 39 = 195
# 6 x 39 = 234
# 7 x 39 = 273
# 8 x 39 = 312
# 9 x 39 = 351
# 10 x 39 = 390
#
# 1 x 40 = 40
# 2 x 40 = 80
# 3 x 40 = 120
# 4 x 40 = 160
# 5 x 40 = 200
# 6 x 40 = 240
# 7 x 40 = 280
# 8 x 40 = 320
# 9 x 40 = 360
# 10 x 40 = 400
#
# 1 x 41 = 41
# 2 x 41 = 82
# 3 x 41 = 123
# 4 x 41 = 164
# 5 x 41 = 205
# 6 x 41 = 246
# 7 x 41 = 287
# 8 x 41 = 328
# 9 x 41 = 369
# 10 x 41 = 410
#
# 1 x 42 = 42
# 2 x 42 = 84
# 3 x 42 = 126
# 4 x 42 = 168
# 5 x 42 = 210
# 6 x 42 = 252
# 7 x 42 = 294
# 8 x 42 = 336
# 9 x 42 = 378
# 10 x 42 = 420
#
# 1 x 43 = 43
# 2 x 43 = 86
# 3 x 43 = 129
# 4 x 43 = 172
# 5 x 43 = 215
# 6 x 43 = 258
# 7 x 43 = 301
# 8 x 43 = 344
# 9 x 43 = 387
# 10 x 43 = 430
#
# 1 x 44 = 44
# 2 x 44 = 88
# 3 x 44 = 132
# 4 x 44 = 176
# 5 x 44 = 220
# 6 x 44 = 264
# 7 x 44 = 308
# 8 x 44 = 352
# 9 x 44 = 396
# 10 x 44 = 440
#
# 1 x 45 = 45
# 2 x 45 = 90
# 3 x 45 = 135
# 4 x 45 = 180
# 5 x 45 = 225
# 6 x 45 = 270
# 7 x 45 = 315
# 8 x 45 = 360
# 9 x 45 = 405
# 10 x 45 = 450
#
# 1 x 46 = 46
# 2 x 46 = 92
# 3 x 46 = 138
# 4 x 46 = 184
# 5 x 46 = 230
# 6 x 46 = 276
# 7 x 46 = 322
# 8 x 46 = 368
# 9 x 46 = 414
# 10 x 46 = 460
#
# 1 x 47 = 47
# 2 x 47 = 94
# 3 x 47 = 141
# 4 x 47 = 188
# 5 x 47 = 235
# 6 x 47 = 282
# 7 x 47 = 329
# 8 x 47 = 376
# 9 x 47 = 423
# 10 x 47 = 470
#
# 1 x 48 = 48
# 2 x 48 = 96
# 3 x 48 = 144
# 4 x 48 = 192
# 5 x 48 = 240
# 6 x 48 = 288
# 7 x 48 = 336
# 8 x 48 = 384
# 9 x 48 = 432
# 10 x 48 = 480
#
# 1 x 49 = 49
# 2 x 49 = 98
# 3 x 49 = 147
# 4 x 49 = 196
# 5 x 49 = 245
# 6 x 49 = 294
# 7 x 49 = 343
# 8 x 49 = 392
# 9 x 49 = 441
# 10 x 49 = 490
#
# 1 x 50 = 50
# 2 x 50 = 100
# 3 x 50 = 150
# 4 x 50 = 200
# 5 x 50 = 250
# 6 x 50 = 300
# 7 x 50 = 350
# 8 x 50 = 400
# 9 x 50 = 450
# 10 x 50 = 500
#
# 1 x 51 = 51
# 2 x 51 = 102
# 3 x 51 = 153
# 4 x 51 = 204
# 5 x 51 = 255
# 6 x 51 = 306
# 7 x 51 = 357
# 8 x 51 = 408
# 9 x 51 = 459
# 10 x 51 = 510
#
# 1 x 52 = 52
# 2 x 52 = 104
# 3 x 52 = 156
# 4 x 52 = 208
# 5 x 52 = 260
# 6 x 52 = 312
# 7 x 52 = 364
# 8 x 52 = 416
# 9 x 52 = 468
# 10 x 52 = 520
#
# 1 x 53 = 53
# 2 x 53 = 106
# 3 x 53 = 159
# 4 x 53 = 212
# 5 x 53 = 265
# 6 x 53 = 318
# 7 x 53 = 371
# 8 x 53 = 424
# 9 x 53 = 477
# 10 x 53 = 530
#
# 1 x 54 = 54
# 2 x 54 = 108
# 3 x 54 = 162
# 4 x 54 = 216
# 5 x 54 = 270
# 6 x 54 = 324
# 7 x 54 = 378
# 8 x 54 = 432
# 9 x 54 = 486
# 10 x 54 = 540
#
# 1 x 55 = 55
# 2 x 55 = 110
# 3 x 55 = 165
# 4 x 55 = 220
# 5 x 55 = 275
# 6 x 55 = 330
# 7 x 55 = 385
# 8 x 55 = 440
# 9 x 55 = 495
# 10 x 55 = 550
#
# 1 x 56 = 56
# 2 x 56 = 112
# 3 x 56 = 168
# 4 x 56 = 224
# 5 x 56 = 280
# 6 x 56 = 336
# 7 x 56 = 392
# 8 x 56 = 448
# 9 x 56 = 504
# 10 x 56 = 560
#
# 1 x 57 = 57
# 2 x 57 = 114
# 3 x 57 = 171
# 4 x 57 = 228
# 5 x 57 = 285
# 6 x 57 = 342
# 7 x 57 = 399
# 8 x 57 = 456
# 9 x 57 = 513
# 10 x 57 = 570
#
# 1 x 58 = 58
# 2 x 58 = 116
# 3 x 58 = 174
# 4 x 58 = 232
# 5 x 58 = 290
# 6 x 58 = 348
# 7 x 58 = 406
# 8 x 58 = 464
# 9 x 58 = 522
# 10 x 58 = 580
#
# 1 x 59 = 59
# 2 x 59 = 118
# 3 x 59 = 177
# 4 x 59 = 236
# 5 x 59 = 295
# 6 x 59 = 354
# 7 x 59 = 413
# 8 x 59 = 472
# 9 x 59 = 531
# 10 x 59 = 590
#
# 1 x 60 = 60
# 2 x 60 = 120
# 3 x 60 = 180
# 4 x 60 = 240
# 5 x 60 = 300
# 6 x 60 = 360
# 7 x 60 = 420
# 8 x 60 = 480
# 9 x 60 = 540
# 10 x 60 = 600
#
# 1 x 61 = 61
# 2 x 61 = 122
# 3 x 61 = 183
# 4 x 61 = 244
# 5 x 61 = 305
# 6 x 61 = 366
# 7 x 61 = 427
# 8 x 61 = 488
# 9 x 61 = 549
# 10 x 61 = 610
#
# 1 x 62 = 62
# 2 x 62 = 124
# 3 x 62 = 186
# 4 x 62 = 248
# 5 x 62 = 310
# 6 x 62 = 372
# 7 x 62 = 434
# 8 x 62 = 496
# 9 x 62 = 558
# 10 x 62 = 620
#
# 1 x 63 = 63
# 2 x 63 = 126
# 3 x 63 = 189
# 4 x 63 = 252
# 5 x 63 = 315
# 6 x 63 = 378
# 7 x 63 = 441
# 8 x 63 = 504
# 9 x 63 = 567
# 10 x 63 = 630
#
# 1 x 64 = 64
# 2 x 64 = 128
# 3 x 64 = 192
# 4 x 64 = 256
# 5 x 64 = 320
# 6 x 64 = 384
# 7 x 64 = 448
# 8 x 64 = 512
# 9 x 64 = 576
# 10 x 64 = 640
#
# 1 x 65 = 65
# 2 x 65 = 130
# 3 x 65 = 195
# 4 x 65 = 260
# 5 x 65 = 325
# 6 x 65 = 390
# 7 x 65 = 455
# 8 x 65 = 520
# 9 x 65 = 585
# 10 x 65 = 650
#
# 1 x 66 = 66
# 2 x 66 = 132
# 3 x 66 = 198
# 4 x 66 = 264
# 5 x 66 = 330
# 6 x 66 = 396
# 7 x 66 = 462
# 8 x 66 = 528
# 9 x 66 = 594
# 10 x 66 = 660
#
# 1 x 67 = 67
# 2 x 67 = 134
# 3 x 67 = 201
# 4 x 67 = 268
# 5 x 67 = 335
# 6 x 67 = 402
# 7 x 67 = 469
# 8 x 67 = 536
# 9 x 67 = 603
# 10 x 67 = 670
#
# 1 x 68 = 68
# 2 x 68 = 136
# 3 x 68 = 204
# 4 x 68 = 272
# 5 x 68 = 340
# 6 x 68 = 408
# 7 x 68 = 476
# 8 x 68 = 544
# 9 x 68 = 612
# 10 x 68 = 680
#
# 1 x 69 = 69
# 2 x 69 = 138
# 3 x 69 = 207
# 4 x 69 = 276
# 5 x 69 = 345
# 6 x 69 = 414
# 7 x 69 = 483
# 8 x 69 = 552
# 9 x 69 = 621
# 10 x 69 = 690
#
# 1 x 70 = 70
# 2 x 70 = 140
# 3 x 70 = 210
# 4 x 70 = 280
# 5 x 70 = 350
# 6 x 70 = 420
# 7 x 70 = 490
# 8 x 70 = 560
# 9 x 70 = 630
# 10 x 70 = 700
#
# 1 x 71 = 71
# 2 x 71 = 142
# 3 x 71 = 213
# 4 x 71 = 284
# 5 x 71 = 355
# 6 x 71 = 426
# 7 x 71 = 497
# 8 x 71 = 568
# 9 x 71 = 639
# 10 x 71 = 710
#
# 1 x 72 = 72
# 2 x 72 = 144
# 3 x 72 = 216
# 4 x 72 = 288
# 5 x 72 = 360
# 6 x 72 = 432
# 7 x 72 = 504
# 8 x 72 = 576
# 9 x 72 = 648
# 10 x 72 = 720
#
# 1 x 73 = 73
# 2 x 73 = 146
# 3 x 73 = 219
# 4 x 73 = 292
# 5 x 73 = 365
# 6 x 73 = 438
# 7 x 73 = 511
# 8 x 73 = 584
# 9 x 73 = 657
# 10 x 73 = 730
#
# 1 x 74 = 74
# 2 x 74 = 148
# 3 x 74 = 222
# 4 x 74 = 296
# 5 x 74 = 370
# 6 x 74 = 444
# 7 x 74 = 518
# 8 x 74 = 592
# 9 x 74 = 666
# 10 x 74 = 740
#
# 1 x 75 = 75
# 2 x 75 = 150
# 3 x 75 = 225
# 4 x 75 = 300
# 5 x 75 = 375
# 6 x 75 = 450
# 7 x 75 = 525
# 8 x 75 = 600
# 9 x 75 = 675
# 10 x 75 = 750
#
# 1 x 76 = 76
# 2 x 76 = 152
# 3 x 76 = 228
# 4 x 76 = 304
# 5 x 76 = 380
# 6 x 76 = 456
# 7 x 76 = 532
# 8 x 76 = 608
# 9 x 76 = 684
# 10 x 76 = 760
#
# 1 x 77 = 77
# 2 x 77 = 154
# 3 x 77 = 231
# 4 x 77 = 308
# 5 x 77 = 385
# 6 x 77 = 462
# 7 x 77 = 539
# 8 x 77 = 616
# 9 x 77 = 693
# 10 x 77 = 770
#
# 1 x 78 = 78
# 2 x 78 = 156
# 3 x 78 = 234
# 4 x 78 = 312
# 5 x 78 = 390
# 6 x 78 = 468
# 7 x 78 = 546
# 8 x 78 = 624
# 9 x 78 = 702
# 10 x 78 = 780
#
# 1 x 79 = 79
# 2 x 79 = 158
# 3 x 79 = 237
# 4 x 79 = 316
# 5 x 79 = 395
# 6 x 79 = 474
# 7 x 79 = 553
# 8 x 79 = 632
# 9 x 79 = 711
# 10 x 79 = 790
#
# 1 x 80 = 80
# 2 x 80 = 160
# 3 x 80 = 240
# 4 x 80 = 320
# 5 x 80 = 400
# 6 x 80 = 480
# 7 x 80 = 560
# 8 x 80 = 640
# 9 x 80 = 720
# 10 x 80 = 800
#
# 1 x 81 = 81
# 2 x 81 = 162
# 3 x 81 = 243
# 4 x 81 = 324
# 5 x 81 = 405
# 6 x 81 = 486
# 7 x 81 = 567
# 8 x 81 = 648
# 9 x 81 = 729
# 10 x 81 = 810
#
# 1 x 82 = 82
# 2 x 82 = 164
# 3 x 82 = 246
# 4 x 82 = 328
# 5 x 82 = 410
# 6 x 82 = 492
# 7 x 82 = 574
# 8 x 82 = 656
# 9 x 82 = 738
# 10 x 82 = 820
#
# 1 x 83 = 83
# 2 x 83 = 166
# 3 x 83 = 249
# 4 x 83 = 332
# 5 x 83 = 415
# 6 x 83 = 498
# 7 x 83 = 581
# 8 x 83 = 664
# 9 x 83 = 747
# 10 x 83 = 830
#
# 1 x 84 = 84
# 2 x 84 = 168
# 3 x 84 = 252
# 4 x 84 = 336
# 5 x 84 = 420
# 6 x 84 = 504
# 7 x 84 = 588
# 8 x 84 = 672
# 9 x 84 = 756
# 10 x 84 = 840
#
# 1 x 85 = 85
# 2 x 85 = 170
# 3 x 85 = 255
# 4 x 85 = 340
# 5 x 85 = 425
# 6 x 85 = 510
# 7 x 85 = 595
# 8 x 85 = 680
# 9 x 85 = 765
# 10 x 85 = 850
#
# 1 x 86 = 86
# 2 x 86 = 172
# 3 x 86 = 258
# 4 x 86 = 344
# 5 x 86 = 430
# 6 x 86 = 516
# 7 x 86 = 602
# 8 x 86 = 688
# 9 x 86 = 774
# 10 x 86 = 860
#
# 1 x 87 = 87
# 2 x 87 = 174
# 3 x 87 = 261
# 4 x 87 = 348
# 5 x 87 = 435
# 6 x 87 = 522
# 7 x 87 = 609
# 8 x 87 = 696
# 9 x 87 = 783
# 10 x 87 = 870
#
# 1 x 88 = 88
# 2 x 88 = 176
# 3 x 88 = 264
# 4 x 88 = 352
# 5 x 88 = 440
# 6 x 88 = 528
# 7 x 88 = 616
# 8 x 88 = 704
# 9 x 88 = 792
# 10 x 88 = 880
#
# 1 x 89 = 89
# 2 x 89 = 178
# 3 x 89 = 267
# 4 x 89 = 356
# 5 x 89 = 445
# 6 x 89 = 534
# 7 x 89 = 623
# 8 x 89 = 712
# 9 x 89 = 801
# 10 x 89 = 890
#
# 1 x 90 = 90
# 2 x 90 = 180
# 3 x 90 = 270
# 4 x 90 = 360
# 5 x 90 = 450
# 6 x 90 = 540
# 7 x 90 = 630
# 8 x 90 = 720
# 9 x 90 = 810
# 10 x 90 = 900
#
# 1 x 91 = 91
# 2 x 91 = 182
# 3 x 91 = 273
# 4 x 91 = 364
# 5 x 91 = 455
# 6 x 91 = 546
# 7 x 91 = 637
# 8 x 91 = 728
# 9 x 91 = 819
# 10 x 91 = 910
#
# 1 x 92 = 92
# 2 x 92 = 184
# 3 x 92 = 276
# 4 x 92 = 368
# 5 x 92 = 460
# 6 x 92 = 552
# 7 x 92 = 644
# 8 x 92 = 736
# 9 x 92 = 828
# 10 x 92 = 920
#
# 1 x 93 = 93
# 2 x 93 = 186
# 3 x 93 = 279
# 4 x 93 = 372
# 5 x 93 = 465
# 6 x 93 = 558
# 7 x 93 = 651
# 8 x 93 = 744
# 9 x 93 = 837
# 10 x 93 = 930
#
# 1 x 94 = 94
# 2 x 94 = 188
# 3 x 94 = 282
# 4 x 94 = 376
# 5 x 94 = 470
# 6 x 94 = 564
# 7 x 94 = 658
# 8 x 94 = 752
# 9 x 94 = 846
# 10 x 94 = 940
#
# 1 x 95 = 95
# 2 x 95 = 190
# 3 x 95 = 285
# 4 x 95 = 380
# 5 x 95 = 475
# 6 x 95 = 570
# 7 x 95 = 665
# 8 x 95 = 760
# 9 x 95 = 855
# 10 x 95 = 950
#
# 1 x 96 = 96
# 2 x 96 = 192
# 3 x 96 = 288
# 4 x 96 = 384
# 5 x 96 = 480
# 6 x 96 = 576
# 7 x 96 = 672
# 8 x 96 = 768
# 9 x 96 = 864
# 10 x 96 = 960
#
# 1 x 97 = 97
# 2 x 97 = 194
# 3 x 97 = 291
# 4 x 97 = 388
# 5 x 97 = 485
# 6 x 97 = 582
# 7 x 97 = 679
# 8 x 97 = 776
# 9 x 97 = 873
# 10 x 97 = 970
#
# 1 x 98 = 98
# 2 x 98 = 196
# 3 x 98 = 294
# 4 x 98 = 392
# 5 x 98 = 490
# 6 x 98 = 588
# 7 x 98 = 686
# 8 x 98 = 784
# 9 x 98 = 882
# 10 x 98 = 980
#
# 1 x 99 = 99
# 2 x 99 = 198
# 3 x 99 = 297
# 4 x 99 = 396
# 5 x 99 = 495
# 6 x 99 = 594
# 7 x 99 = 693
# 8 x 99 = 792
# 9 x 99 = 891
# 10 x 99 = 990
#
# 1 x 100 = 100
# 2 x 100 = 200
# 3 x 100 = 300
# 4 x 100 = 400
# 5 x 100 = 500
# 6 x 100 = 600
# 7 x 100 = 700
# 8 x 100 = 800
# 9 x 100 = 900
# 10 x 100 = 1000
#
# 1 x 101 = 101
# 2 x 101 = 202
# 3 x 101 = 303
# 4 x 101 = 404
# 5 x 101 = 505
# 6 x 101 = 606
# 7 x 101 = 707
# 8 x 101 = 808
# 9 x 101 = 909
# 10 x 101 = 1010
#
# 1 x 102 = 102
# 2 x 102 = 204
# 3 x 102 = 306
# 4 x 102 = 408
# 5 x 102 = 510
# 6 x 102 = 612
# 7 x 102 = 714
# 8 x 102 = 816
# 9 x 102 = 918
# 10 x 102 = 1020
#
# 1 x 103 = 103
# 2 x 103 = 206
# 3 x 103 = 309
# 4 x 103 = 412
# 5 x 103 = 515
# 6 x 103 = 618
# 7 x 103 = 721
# 8 x 103 = 824
# 9 x 103 = 927
# 10 x 103 = 1030
#
# 1 x 104 = 104
# 2 x 104 = 208
# 3 x 104 = 312
# 4 x 104 = 416
# 5 x 104 = 520
# 6 x 104 = 624
# 7 x 104 = 728
# 8 x 104 = 832
# 9 x 104 = 936
# 10 x 104 = 1040
#
# 1 x 105 = 105
# 2 x 105 = 210
# 3 x 105 = 315
# 4 x 105 = 420
# 5 x 105 = 525
# 6 x 105 = 630
# 7 x 105 = 735
# 8 x 105 = 840
# 9 x 105 = 945
# 10 x 105 = 1050
#
# 1 x 106 = 106
# 2 x 106 = 212
# 3 x 106 = 318
# 4 x 106 = 424
# 5 x 106 = 530
# 6 x 106 = 636
# 7 x 106 = 742
# 8 x 106 = 848
# 9 x 106 = 954
# 10 x 106 = 1060
#
# 1 x 107 = 107
# 2 x 107 = 214
# 3 x 107 = 321
# 4 x 107 = 428
# 5 x 107 = 535
# 6 x 107 = 642
# 7 x 107 = 749
# 8 x 107 = 856
# 9 x 107 = 963
# 10 x 107 = 1070
#
# 1 x 108 = 108
# 2 x 108 = 216
# 3 x 108 = 324
# 4 x 108 = 432
# 5 x 108 = 540
# 6 x 108 = 648
# 7 x 108 = 756
# 8 x 108 = 864
# 9 x 108 = 972
# 10 x 108 = 1080
#
# 1 x 109 = 109
# 2 x 109 = 218
# 3 x 109 = 327
# 4 x 109 = 436
# 5 x 109 = 545
# 6 x 109 = 654
# 7 x 109 = 763
# 8 x 109 = 872
# 9 x 109 = 981
# 10 x 109 = 1090
#
# 1 x 110 = 110
# 2 x 110 = 220
# 3 x 110 = 330
# 4 x 110 = 440
# 5 x 110 = 550
# 6 x 110 = 660
# 7 x 110 = 770
# 8 x 110 = 880
# 9 x 110 = 990
# 10 x 110 = 1100
#
# 1 x 111 = 111
# 2 x 111 = 222
# 3 x 111 = 333
# 4 x 111 = 444
# 5 x 111 = 555
# 6 x 111 = 666
# 7 x 111 = 777
# 8 x 111 = 888
# 9 x 111 = 999
# 10 x 111 = 1110
#
# 1 x 112 = 112
# 2 x 112 = 224
# 3 x 112 = 336
# 4 x 112 = 448
# 5 x 112 = 560
# 6 x 112 = 672
# 7 x 112 = 784
# 8 x 112 = 896
# 9 x 112 = 1008
# 10 x 112 = 1120
#
# 1 x 113 = 113
# 2 x 113 = 226
# 3 x 113 = 339
# 4 x 113 = 452
# 5 x 113 = 565
# 6 x 113 = 678
# 7 x 113 = 791
# 8 x 113 = 904
# 9 x 113 = 1017
# 10 x 113 = 1130
#
# 1 x 114 = 114
# 2 x 114 = 228
# 3 x 114 = 342
# 4 x 114 = 456
# 5 x 114 = 570
# 6 x 114 = 684
# 7 x 114 = 798
# 8 x 114 = 912
# 9 x 114 = 1026
# 10 x 114 = 1140
#
# 1 x 115 = 115
# 2 x 115 = 230
# 3 x 115 = 345
# 4 x 115 = 460
# 5 x 115 = 575
# 6 x 115 = 690
# 7 x 115 = 805
# 8 x 115 = 920
# 9 x 115 = 1035
# 10 x 115 = 1150
#
# 1 x 116 = 116
# 2 x 116 = 232
# 3 x 116 = 348
# 4 x 116 = 464
# 5 x 116 = 580
# 6 x 116 = 696
# 7 x 116 = 812
# 8 x 116 = 928
# 9 x 116 = 1044
# 10 x 116 = 1160
#
# 1 x 117 = 117
# 2 x 117 = 234
# 3 x 117 = 351
# 4 x 117 = 468
# 5 x 117 = 585
# 6 x 117 = 702
# 7 x 117 = 819
# 8 x 117 = 936
# 9 x 117 = 1053
# 10 x 117 = 1170
#
# 1 x 118 = 118
# 2 x 118 = 236
# 3 x 118 = 354
# 4 x 118 = 472
# 5 x 118 = 590
# 6 x 118 = 708
# 7 x 118 = 826
# 8 x 118 = 944
# 9 x 118 = 1062
# 10 x 118 = 1180
#
# 1 x 119 = 119
# 2 x 119 = 238
# 3 x 119 = 357
# 4 x 119 = 476
# 5 x 119 = 595
# 6 x 119 = 714
# 7 x 119 = 833
# 8 x 119 = 952
# 9 x 119 = 1071
# 10 x 119 = 1190
#
# 1 x 120 = 120
# 2 x 120 = 240
# 3 x 120 = 360
# 4 x 120 = 480
# 5 x 120 = 600
# 6 x 120 = 720
# 7 x 120 = 840
# 8 x 120 = 960
# 9 x 120 = 1080
# 10 x 120 = 1200
#
# 1 x 121 = 121
# 2 x 121 = 242
# 3 x 121 = 363
# 4 x 121 = 484
# 5 x 121 = 605
# 6 x 121 = 726
# 7 x 121 = 847
# 8 x 121 = 968
# 9 x 121 = 1089
# 10 x 121 = 1210
#
# 1 x 122 = 122
# 2 x 122 = 244
# 3 x 122 = 366
# 4 x 122 = 488
# 5 x 122 = 610
# 6 x 122 = 732
# 7 x 122 = 854
# 8 x 122 = 976
# 9 x 122 = 1098
# 10 x 122 = 1220
#
# 1 x 123 = 123
# 2 x 123 = 246
# 3 x 123 = 369
# 4 x 123 = 492
# 5 x 123 = 615
# 6 x 123 = 738
# 7 x 123 = 861
# 8 x 123 = 984
# 9 x 123 = 1107
# 10 x 123 = 1230
#
# 1 x 124 = 124
# 2 x 124 = 248
# 3 x 124 = 372
# 4 x 124 = 496
# 5 x 124 = 620
# 6 x 124 = 744
# 7 x 124 = 868
# 8 x 124 = 992
# 9 x 124 = 1116
# 10 x 124 = 1240
#
# 1 x 125 = 125
# 2 x 125 = 250
# 3 x 125 = 375
# 4 x 125 = 500
# 5 x 125 = 625
# 6 x 125 = 750
# 7 x 125 = 875
# 8 x 125 = 1000
# 9 x 125 = 1125
# 10 x 125 = 1250
#
# 1 x 126 = 126
# 2 x 126 = 252
# 3 x 126 = 378
# 4 x 126 = 504
# 5 x 126 = 630
# 6 x 126 = 756
# 7 x 126 = 882
# 8 x 126 = 1008
# 9 x 126 = 1134
# 10 x 126 = 1260
#
# 1 x 127 = 127
# 2 x 127 = 254
# 3 x 127 = 381
# 4 x 127 = 508
# 5 x 127 = 635
# 6 x 127 = 762
# 7 x 127 = 889
# 8 x 127 = 1016
# 9 x 127 = 1143
# 10 x 127 = 1270
#
# 1 x 128 = 128
# 2 x 128 = 256
# 3 x 128 = 384
# 4 x 128 = 512
# 5 x 128 = 640
# 6 x 128 = 768
# 7 x 128 = 896
# 8 x 128 = 1024
# 9 x 128 = 1152
# 10 x 128 = 1280
#
# 1 x 129 = 129
# 2 x 129 = 258
# 3 x 129 = 387
# 4 x 129 = 516
# 5 x 129 = 645
# 6 x 129 = 774
# 7 x 129 = 903
# 10 x 141 = 1410
#
# 1 x 142 = 142
# 2 x 142 = 284
# 3 x 142 = 426
# 4 x 142 = 568
# 5 x 142 = 710
# 6 x 142 = 852
# 7 x 142 = 994
# 8 x 142 = 1136
# 9 x 142 = 1278
# 10 x 142 = 1420
#
# 1 x 143 = 143
# 2 x 143 = 286
# 3 x 143 = 429
# 4 x 143 = 572
# 5 x 143 = 715
# 6 x 143 = 858
# 7 x 143 = 1001
# 8 x 143 = 1144
# 9 x 143 = 1287
# 10 x 143 = 1430
#
# 1 x 144 = 144
# 2 x 144 = 288
# 3 x 144 = 432
# 4 x 144 = 576
# 5 x 144 = 720
# 6 x 144 = 864
# 7 x 144 = 1008
# 8 x 144 = 1152
# 9 x 144 = 1296
# 10 x 144 = 1440
#
# 1 x 145 = 145
# 2 x 145 = 290
# 3 x 145 = 435
# 4 x 145 = 580
# 5 x 145 = 725
# 6 x 145 = 870
# 7 x 145 = 1015
# 8 x 145 = 1160
# 9 x 145 = 1305
# 10 x 145 = 1450
#
# 1 x 146 = 146
# 2 x 146 = 292
# 3 x 146 = 438
# 4 x 146 = 584
# 5 x 146 = 730
# 6 x 146 = 876
# 7 x 146 = 1022
# 8 x 146 = 1168
# 9 x 146 = 1314
# 10 x 146 = 1460
#
# 1 x 147 = 147
# 2 x 147 = 294
# 3 x 147 = 441
# 4 x 147 = 588
# 5 x 147 = 735
# 6 x 147 = 882
# 7 x 147 = 1029
# 8 x 147 = 1176
# 9 x 147 = 1323
# 10 x 147 = 1470
#
# 1 x 148 = 148
# 2 x 148 = 296
# 3 x 148 = 444
# 4 x 148 = 592
# 5 x 148 = 740
# 6 x 148 = 888
# 7 x 148 = 1036
# 8 x 148 = 1184
# 9 x 148 = 1332
# 10 x 148 = 1480
#
# 1 x 149 = 149
# 2 x 149 = 298
# 3 x 149 = 447
# 4 x 149 = 596
# 5 x 149 = 745
# 6 x 149 = 894
# 7 x 149 = 1043
# 8 x 149 = 1192
# 9 x 149 = 1341
# 10 x 149 = 1490
#
# 1 x 150 = 150
# 2 x 150 = 300
# 3 x 150 = 450
# 4 x 150 = 600
# 5 x 150 = 750
# 6 x 150 = 900
# 7 x 150 = 1050
# 8 x 150 = 1200
# 9 x 150 = 1350
# 10 x 150 = 1500
#
# 1 x 151 = 151
# 2 x 151 = 302
# 3 x 151 = 453
# 4 x 151 = 604
# 5 x 151 = 755
# 6 x 151 = 906
# 7 x 151 = 1057
# 8 x 151 = 1208
# 9 x 151 = 1359
# 10 x 151 = 1510
#
# 1 x 152 = 152
# 2 x 152 = 304
# 3 x 152 = 456
# 4 x 152 = 608
# 5 x 152 = 760
# 6 x 152 = 912
# 7 x 152 = 1064
# 8 x 152 = 1216
# 9 x 152 = 1368
# 10 x 152 = 1520
#
# 1 x 153 = 153
# 2 x 153 = 306
# 3 x 153 = 459
# 4 x 153 = 612
# 5 x 153 = 765
# 6 x 153 = 918
# 7 x 153 = 1071
# 8 x 153 = 1224
# 9 x 153 = 1377
# 10 x 153 = 1530
#
# 1 x 154 = 154
# 2 x 154 = 308
# 3 x 154 = 462
# 4 x 154 = 616
# 5 x 154 = 770
# 6 x 154 = 924
# 7 x 154 = 1078
# 8 x 154 = 1232
# 9 x 154 = 1386
# 10 x 154 = 1540
#
# 1 x 155 = 155
# 2 x 155 = 310
# 3 x 155 = 465
# 4 x 155 = 620
# 5 x 155 = 775
# 6 x 155 = 930
# 7 x 155 = 1085
# 8 x 155 = 1240
# 9 x 155 = 1395
# 10 x 155 = 1550
#
# 1 x 156 = 156
# 2 x 156 = 312
# 3 x 156 = 468
# 4 x 156 = 624
# 5 x 156 = 780
# 6 x 156 = 936
# 7 x 156 = 1092
# 8 x 156 = 1248
# 9 x 156 = 1404
# 10 x 156 = 1560
#
# 1 x 157 = 157
# 2 x 157 = 314
# 3 x 157 = 471
# 4 x 157 = 628
# 5 x 157 = 785
# 6 x 157 = 942
# 7 x 157 = 1099
# 8 x 157 = 1256
# 9 x 157 = 1413
# 10 x 157 = 1570
#
# 1 x 158 = 158
# 2 x 158 = 316
# 3 x 158 = 474
# 4 x 158 = 632
# 5 x 158 = 790
# 6 x 158 = 948
# 7 x 158 = 1106
# 8 x 158 = 1264
# 9 x 158 = 1422
# 10 x 158 = 1580
#
# 1 x 159 = 159
# 2 x 159 = 318
# 3 x 159 = 477
# 4 x 159 = 636
# 5 x 159 = 795
# 6 x 159 = 954
# 7 x 159 = 1113
# 8 x 159 = 1272
# 9 x 159 = 1431
# 10 x 159 = 1590
#
# 1 x 160 = 160
# 2 x 160 = 320
# 3 x 160 = 480
# 4 x 160 = 640
# 5 x 160 = 800
# 6 x 160 = 960
# 7 x 160 = 1120
# 8 x 160 = 1280
# 9 x 160 = 1440
# 10 x 160 = 1600
#
# 1 x 161 = 161
# 2 x 161 = 322
# 3 x 161 = 483
# 4 x 161 = 644
# 5 x 161 = 805
# 6 x 161 = 966
# 7 x 161 = 1127
# 8 x 161 = 1288
# 9 x 161 = 1449
# 10 x 161 = 1610
#
# 1 x 162 = 162
# 2 x 162 = 324
# 3 x 162 = 486
# 4 x 162 = 648
# 5 x 162 = 810
# 6 x 162 = 972
# 7 x 162 = 1134
# 8 x 162 = 1296
# 9 x 162 = 1458
# 10 x 162 = 1620
#
# 1 x 163 = 163
# 2 x 163 = 326
# 3 x 163 = 489
# 4 x 163 = 652
# 5 x 163 = 815
# 6 x 163 = 978
# 7 x 163 = 1141
# 8 x 163 = 1304
# 9 x 163 = 1467
# 10 x 163 = 1630
#
# 1 x 164 = 164
# 2 x 164 = 328
# 3 x 164 = 492
# 4 x 164 = 656
# 5 x 164 = 820
# 6 x 164 = 984
# 7 x 164 = 1148
# 8 x 164 = 1312
# 9 x 164 = 1476
# 10 x 164 = 1640
#
# 1 x 165 = 165
# 2 x 165 = 330
# 3 x 165 = 495
# 4 x 165 = 660
# 5 x 165 = 825
# 6 x 165 = 990
# 7 x 165 = 1155
# 8 x 165 = 1320
# 9 x 165 = 1485
# 10 x 165 = 1650
#
# 1 x 166 = 166
# 2 x 166 = 332
# 3 x 166 = 498
# 4 x 166 = 664
# 5 x 166 = 830
# 6 x 166 = 996
# 7 x 166 = 1162
# 8 x 166 = 1328
# 9 x 166 = 1494
# 10 x 166 = 1660
#
# 1 x 167 = 167
# 2 x 167 = 334
# 3 x 167 = 501
# 4 x 167 = 668
# 5 x 167 = 835
# 6 x 167 = 1002
# 7 x 167 = 1169
# 8 x 167 = 1336
# 9 x 167 = 1503
# 10 x 167 = 1670
#
# 1 x 168 = 168
# 2 x 168 = 336
# 3 x 168 = 504
# 4 x 168 = 672
# 5 x 168 = 840
# 6 x 168 = 1008
# 7 x 168 = 1176
# 8 x 168 = 1344
# 9 x 168 = 1512
# 10 x 168 = 1680
#
# 1 x 169 = 169
# 2 x 169 = 338
# 3 x 169 = 507
# 4 x 169 = 676
# 5 x 169 = 845
# 6 x 169 = 1014
# 7 x 169 = 1183
# 8 x 169 = 1352
# 9 x 169 = 1521
# 10 x 169 = 1690
#
# 1 x 170 = 170
# 2 x 170 = 340
# 3 x 170 = 510
# 4 x 170 = 680
# 5 x 170 = 850
# 6 x 170 = 1020
# 7 x 170 = 1190
# 8 x 170 = 1360
# 9 x 170 = 1530
# 10 x 170 = 1700
#
# 1 x 171 = 171
# 2 x 171 = 342
# 3 x 171 = 513
# 4 x 171 = 684
# 5 x 171 = 855
# 6 x 171 = 1026
# 7 x 171 = 1197
# 8 x 171 = 1368
# 9 x 171 = 1539
# 10 x 171 = 1710
#
# 1 x 172 = 172
# 2 x 172 = 344
# 3 x 172 = 516
# 4 x 172 = 688
# 5 x 172 = 860
# 6 x 172 = 1032
# 7 x 172 = 1204
# 8 x 172 = 1376
# 9 x 172 = 1548
# 10 x 172 = 1720
#
# 1 x 173 = 173
# 2 x 173 = 346
# 3 x 173 = 519
# 4 x 173 = 692
# 5 x 173 = 865
# 6 x 173 = 1038
# 7 x 173 = 1211
# 8 x 173 = 1384
# 9 x 173 = 1557
# 10 x 173 = 1730
#
# 1 x 174 = 174
# 2 x 174 = 348
# 3 x 174 = 522
# 4 x 174 = 696
# 5 x 174 = 870
# 6 x 174 = 1044
# 7 x 174 = 1218
# 8 x 174 = 1392
# 9 x 174 = 1566
# 10 x 174 = 1740
#
# 1 x 175 = 175
# 2 x 175 = 350
# 3 x 175 = 525
# 4 x 175 = 700
# 5 x 175 = 875
# 6 x 175 = 1050
# 7 x 175 = 1225
# 8 x 175 = 1400
# 9 x 175 = 1575
# 10 x 175 = 1750
#
# 1 x 176 = 176
# 2 x 176 = 352
# 3 x 176 = 528
# 4 x 176 = 704
# 5 x 176 = 880
# 6 x 176 = 1056
# 7 x 176 = 1232
# 8 x 176 = 1408
# 9 x 176 = 1584
# 10 x 176 = 1760
#
# 1 x 177 = 177
# 2 x 177 = 354
# 3 x 177 = 531
# 4 x 177 = 708
# 5 x 177 = 885
# 6 x 177 = 1062
# 7 x 177 = 1239
# 8 x 177 = 1416
# 9 x 177 = 1593
# 10 x 177 = 1770
#
#
# 1 x 190 = 190
# 2 x 190 = 380
# 3 x 190 = 570
# 4 x 190 = 760
# 5 x 190 = 950
# 6 x 190 = 1140
# 7 x 190 = 1330
# 8 x 190 = 1520
# 9 x 190 = 1710
# 10 x 190 = 1900
#
# 1 x 191 = 191
# 2 x 191 = 382
# 3 x 191 = 573
# 4 x 191 = 764
# 5 x 191 = 955
# 6 x 191 = 1146
# 7 x 191 = 1337
# 8 x 191 = 1528
# 9 x 191 = 1719
# 10 x 191 = 1910
#
# 1 x 192 = 192
# 2 x 192 = 384
# 3 x 192 = 576
# 4 x 192 = 768
# 5 x 192 = 960
# 6 x 192 = 1152
# 7 x 192 = 1344
# 8 x 192 = 1536
# 9 x 192 = 1728
# 10 x 192 = 1920
#
# 1 x 193 = 193
# 2 x 193 = 386
# 3 x 193 = 579
# 4 x 193 = 772
# 5 x 193 = 965
# 6 x 193 = 1158
# 7 x 193 = 1351
# 8 x 193 = 1544
# 9 x 193 = 1737
# 10 x 193 = 1930
#
# 1 x 194 = 194
# 2 x 194 = 388
# 3 x 194 = 582
# 4 x 194 = 776
# 5 x 194 = 970
# 6 x 194 = 1164
# 7 x 194 = 1358
# 8 x 194 = 1552
# 9 x 194 = 1746
# 10 x 194 = 1940
#
# 1 x 195 = 195
# 2 x 195 = 390
# 3 x 195 = 585
# 4 x 195 = 780
# 5 x 195 = 975
# 6 x 195 = 1170
# 7 x 195 = 1365
# 8 x 195 = 1560
# 9 x 195 = 1755
# 10 x 195 = 1950
#
# 1 x 196 = 196
# 2 x 196 = 392
# 3 x 196 = 588
# 4 x 196 = 784
# 5 x 196 = 980
# 6 x 196 = 1176
# 7 x 196 = 1372
# 8 x 196 = 1568
# 9 x 196 = 1764
# 10 x 196 = 1960
#
# 1 x 197 = 197
# 2 x 197 = 394
# 3 x 197 = 591
# 4 x 197 = 788
# 5 x 197 = 985
# 6 x 197 = 1182
# 7 x 197 = 1379
# 8 x 197 = 1576
# 9 x 197 = 1773
# 10 x 197 = 1970
#
# 1 x 198 = 198
# 2 x 198 = 396
# 3 x 198 = 594
# 4 x 198 = 792
# 5 x 198 = 990
# 6 x 198 = 1188
# 7 x 198 = 1386
# 8 x 198 = 1584
# 9 x 198 = 1782
# 10 x 198 = 1980
#
# 1 x 199 = 199
# 2 x 199 = 398
# 3 x 199 = 597
# 4 x 199 = 796
# 5 x 199 = 995
# 6 x 199 = 1194
# 7 x 199 = 1393
# 8 x 199 = 1592
# 9 x 199 = 1791
# 10 x 199 = 1990
#
# 1 x 200 = 200
# 2 x 200 = 400
# 3 x 200 = 600
# 4 x 200 = 800
# 5 x 200 = 1000
# 6 x 200 = 1200
# 7 x 200 = 1400
# 8 x 200 = 1600
# 9 x 200 = 1800
# 10 x 200 = 2000
#
# 1 x 201 = 201
# 2 x 201 = 402
# 3 x 201 = 603
# 4 x 201 = 804
# 5 x 201 = 1005
# 6 x 201 = 1206
# 7 x 201 = 1407
# 8 x 201 = 1608
# 9 x 201 = 1809
# 10 x 201 = 2010
#
# 1 x 202 = 202
# 2 x 202 = 404
# 3 x 202 = 606
# 4 x 202 = 808
# 5 x 202 = 1010
# 6 x 202 = 1212
# 7 x 202 = 1414
# 8 x 202 = 1616
# 9 x 202 = 1818
# 10 x 202 = 2020
#
# 1 x 203 = 203
# 2 x 203 = 406
# 3 x 203 = 609
# 4 x 203 = 812
# 5 x 203 = 1015
# 6 x 203 = 1218
# 7 x 203 = 1421
# 8 x 203 = 1624
# 9 x 203 = 1827
# 10 x 203 = 2030
#
# 1 x 204 = 204
# 2 x 204 = 408
# 3 x 204 = 612
# 4 x 204 = 816
# 5 x 204 = 1020
# 6 x 204 = 1224
# 7 x 204 = 1428
# 8 x 204 = 1632
# 9 x 204 = 1836
# 10 x 204 = 2040
#
# 1 x 205 = 205
# 2 x 205 = 410
# 3 x 205 = 615
# 4 x 205 = 820
# 5 x 205 = 1025
# 6 x 205 = 1230
# 7 x 205 = 1435
# 8 x 205 = 1640
# 9 x 205 = 1845
# 10 x 205 = 2050
#
# 1 x 206 = 206
# 2 x 206 = 412
# 3 x 206 = 618
# 4 x 206 = 824
# 5 x 206 = 1030
# 6 x 206 = 1236
# 7 x 206 = 1442
# 8 x 206 = 1648
# 9 x 206 = 1854
# 10 x 206 = 2060
#
# 1 x 207 = 207
# 2 x 207 = 414
# 3 x 207 = 621
# 4 x 207 = 828
# 5 x 207 = 1035
# 6 x 207 = 1242
# 7 x 207 = 1449
# 8 x 207 = 1656
# 9 x 207 = 1863
# 10 x 207 = 2070
#
# 1 x 208 = 208
# 2 x 208 = 416
# 3 x 208 = 624
# 4 x 208 = 832
# 5 x 208 = 1040
# 6 x 208 = 1248
# 7 x 208 = 1456
# 8 x 208 = 1664
# 9 x 208 = 1872
# 10 x 208 = 2080
#
# 1 x 209 = 209
# 2 x 209 = 418
# 3 x 209 = 627
# 4 x 209 = 836
# 5 x 209 = 1045
# 6 x 209 = 1254
# 7 x 209 = 1463
# 8 x 209 = 1672
# 9 x 209 = 1881
# 10 x 209 = 2090
#
# 1 x 210 = 210
# 2 x 210 = 420
# 3 x 210 = 630
# 4 x 210 = 840
# 5 x 210 = 1050
# 6 x 210 = 1260
# 7 x 210 = 1470
# 8 x 210 = 1680
# 9 x 210 = 1890
# 10 x 210 = 2100
#
# 1 x 211 = 211
# 2 x 211 = 422
# 3 x 211 = 633
# 4 x 211 = 844
# 5 x 211 = 1055
# 6 x 211 = 1266
# 7 x 211 = 1477
# 8 x 211 = 1688
# 9 x 211 = 1899
# 10 x 211 = 2110
#
# 1 x 212 = 212
# 2 x 212 = 424
# 3 x 212 = 636
# 4 x 212 = 848
# 5 x 212 = 1060
# 6 x 212 = 1272
# 7 x 212 = 1484
# 8 x 212 = 1696
# 9 x 212 = 1908
# 10 x 212 = 2120
#
# 1 x 213 = 213
# 2 x 213 = 426
# 3 x 213 = 639
# 4 x 213 = 852
# 5 x 213 = 1065
# 6 x 213 = 1278
# 7 x 213 = 1491
# 8 x 213 = 1704
# 8 x 225 = 1800
# 9 x 225 = 2025
# 10 x 225 = 2250
#
# 1 x 226 = 226
# 2 x 226 = 452
# 3 x 226 = 678
# 4 x 226 = 904
# 5 x 226 = 1130
# 6 x 226 = 1356
# 7 x 226 = 1582
# 8 x 226 = 1808
# 9 x 226 = 2034
# 10 x 226 = 2260
#
# 1 x 227 = 227
# 2 x 227 = 454
# 3 x 227 = 681
# 4 x 227 = 908
# 5 x 227 = 1135
# 6 x 227 = 1362
# 7 x 227 = 1589
# 8 x 227 = 1816
# 9 x 227 = 2043
# 10 x 227 = 2270
#
# 1 x 228 = 228
# 2 x 228 = 456
# 3 x 228 = 684
# 4 x 228 = 912
# 5 x 228 = 1140
# 6 x 228 = 1368
# 7 x 228 = 1596
# 8 x 228 = 1824
# 9 x 228 = 2052
# 10 x 228 = 2280
#
# 1 x 229 = 229
# 2 x 229 = 458
# 3 x 229 = 687
# 4 x 229 = 916
# 5 x 229 = 1145
# 6 x 229 = 1374
# 7 x 229 = 1603
# 8 x 229 = 1832
# 9 x 229 = 2061
# 10 x 229 = 2290
#
# 1 x 230 = 230
# 2 x 230 = 460
# 3 x 230 = 690
# 4 x 230 = 920
# 5 x 230 = 1150
# 6 x 230 = 1380
# 7 x 230 = 1610
# 8 x 230 = 1840
# 9 x 230 = 2070
# 10 x 230 = 2300
#
# 1 x 231 = 231
# 2 x 231 = 462
# 3 x 231 = 693
# 4 x 231 = 924
# 5 x 231 = 1155
# 6 x 231 = 1386
# 7 x 231 = 1617
# 8 x 231 = 1848
# 9 x 231 = 2079
# 10 x 231 = 2310
#
# 1 x 232 = 232
# 2 x 232 = 464
# 3 x 232 = 696
# 4 x 232 = 928
# 5 x 232 = 1160
# 6 x 232 = 1392
# 7 x 232 = 1624
# 8 x 232 = 1856
# 9 x 232 = 2088
# 10 x 232 = 2320
#
# 1 x 233 = 233
# 2 x 233 = 466
# 3 x 233 = 699
# 4 x 233 = 932
# 5 x 233 = 1165
# 6 x 233 = 1398
# 7 x 233 = 1631
# 8 x 233 = 1864
# 9 x 233 = 2097
# 10 x 233 = 2330
#
# 1 x 234 = 234
# 2 x 234 = 468
# 3 x 234 = 702
# 4 x 234 = 936
# 5 x 234 = 1170
# 6 x 234 = 1404
# 7 x 234 = 1638
# 8 x 234 = 1872
# 9 x 234 = 2106
# 10 x 234 = 2340
#
# 1 x 235 = 235
# 2 x 235 = 470
# 3 x 235 = 705
# 4 x 235 = 940
# 5 x 235 = 1175
# 6 x 235 = 1410
# 7 x 235 = 1645
# 8 x 235 = 1880
# 9 x 235 = 2115
# 10 x 235 = 2350
#
# 1 x 236 = 236
# 2 x 236 = 472
# 3 x 236 = 708
# 4 x 236 = 944
# 5 x 236 = 1180
# 6 x 236 = 1416
# 7 x 236 = 1652
# 8 x 236 = 1888
# 9 x 236 = 2124
# 10 x 236 = 2360
#
# 1 x 237 = 237
# 2 x 237 = 474
# 3 x 237 = 711
# 4 x 237 = 948
# 5 x 237 = 1185
# 6 x 237 = 1422
# 6 x 249 = 1494
# 7 x 249 = 1743
# 8 x 249 = 1992
# 9 x 249 = 2241
# 10 x 249 = 2490
#
# 1 x 250 = 250
# 2 x 250 = 500
# 3 x 250 = 750
# 4 x 250 = 1000
# 5 x 250 = 1250
# 6 x 250 = 1500
# 7 x 250 = 1750
# 8 x 250 = 2000
# 9 x 250 = 2250
# 10 x 250 = 2500
#
# 1 x 251 = 251
# 2 x 251 = 502
# 3 x 251 = 753
# 4 x 251 = 1004
# 5 x 251 = 1255
# 6 x 251 = 1506
# 7 x 251 = 1757
# 8 x 251 = 2008
# 9 x 251 = 2259
# 10 x 251 = 2510
#
# 1 x 252 = 252
# 2 x 252 = 504
# 3 x 252 = 756
# 4 x 252 = 1008
# 5 x 252 = 1260
# 6 x 252 = 1512
# 7 x 252 = 1764
# 8 x 252 = 2016
# 9 x 252 = 2268
# 10 x 252 = 2520
#
# 1 x 253 = 253
# 2 x 253 = 506
# 3 x 253 = 759
# 4 x 253 = 1012
# 5 x 253 = 1265
# 6 x 253 = 1518
# 7 x 253 = 1771
# 8 x 253 = 2024
# 9 x 253 = 2277
# 10 x 253 = 2530
#
# 1 x 254 = 254
# 2 x 254 = 508
# 3 x 254 = 762
# 4 x 254 = 1016
# 5 x 254 = 1270
# 6 x 254 = 1524
# 7 x 254 = 1778
# 8 x 254 = 2032
# 9 x 254 = 2286
# 10 x 254 = 2540
#
# 1 x 255 = 255
# 2 x 255 = 510
# 3 x 255 = 765
# 4 x 255 = 1020
# 5 x 255 = 1275
# 6 x 255 = 1530
# 7 x 255 = 1785
# 8 x 255 = 2040
# 9 x 255 = 2295
# 10 x 255 = 2550
#
# 1 x 256 = 256
# 2 x 256 = 512
# 3 x 256 = 768
# 4 x 256 = 1024
# 5 x 256 = 1280
# 6 x 256 = 1536
# 7 x 256 = 1792
# 8 x 256 = 2048
# 9 x 256 = 2304
# 10 x 256 = 2560
#
# 1 x 257 = 257
# 2 x 257 = 514
# 3 x 257 = 771
# 4 x 257 = 1028
# 5 x 257 = 1285
# 6 x 257 = 1542
# 7 x 257 = 1799
# 8 x 257 = 2056
# 9 x 257 = 2313
# 10 x 257 = 2570
#
# 1 x 258 = 258
# 2 x 258 = 516
# 3 x 258 = 774
# 4 x 258 = 1032
# 5 x 258 = 1290
# 6 x 258 = 1548
# 7 x 258 = 1806
# 8 x 258 = 2064
# 9 x 258 = 2322
# 10 x 258 = 2580
#
# 1 x 259 = 259
# 2 x 259 = 518
# 3 x 259 = 777
# 4 x 259 = 1036
# 5 x 259 = 1295
# 6 x 259 = 1554
# 7 x 259 = 1813
# 8 x 259 = 2072
# 9 x 259 = 2331
# 10 x 259 = 2590
#
# 1 x 260 = 260
# 2 x 260 = 520
# 3 x 260 = 780
# 4 x 260 = 1040
# 5 x 260 = 1300
# 6 x 260 = 1560
# 7 x 260 = 1820
# 8 x 260 = 2080
# 9 x 260 = 2340
# 10 x 260 = 2600
#
# 1 x 261 = 261
# 2 x 261 = 522
# 3 x 261 = 783
# 4 x 261 = 1044
# 5 x 261 = 1305
# 6 x 261 = 1566
# 7 x 261 = 1827
# 8 x 261 = 2088
# 9 x 261 = 2349
# 10 x 261 = 2610
#
# 1 x 262 = 262
# 2 x 262 = 524
# 3 x 262 = 786
# 4 x 262 = 1048
# 5 x 262 = 1310
# 6 x 262 = 1572
# 7 x 262 = 1834
# 8 x 262 = 2096
# 9 x 262 = 2358
# 10 x 262 = 2620
#
# 1 x 263 = 263
# 2 x 263 = 526
# 3 x 263 = 789
# 4 x 263 = 1052
# 5 x 263 = 1315
# 6 x 263 = 1578
# 7 x 263 = 1841
# 8 x 263 = 2104
# 9 x 263 = 2367
# 10 x 263 = 2630
#
# 1 x 264 = 264
# 2 x 264 = 528
# 3 x 264 = 792
# 4 x 264 = 1056
# 5 x 264 = 1320
# 6 x 264 = 1584
# 7 x 264 = 1848
# 8 x 264 = 2112
# 9 x 264 = 2376
# 10 x 264 = 2640
#
# 1 x 265 = 265
# 2 x 265 = 530
# 3 x 265 = 795
# 4 x 265 = 1060
# 5 x 265 = 1325
# 6 x 265 = 1590
# 7 x 265 = 1855
# 8 x 265 = 2120
# 9 x 265 = 2385
# 10 x 265 = 2650
#
# 1 x 266 = 266
# 2 x 266 = 532
# 3 x 266 = 798
# 4 x 266 = 1064
# 5 x 266 = 1330
# 6 x 266 = 1596
# 7 x 266 = 1862
# 8 x 266 = 2128
# 9 x 266 = 2394
# 10 x 266 = 2660
#
# 1 x 267 = 267
# 2 x 267 = 534
# 3 x 267 = 801
# 4 x 267 = 1068
# 5 x 267 = 1335
# 6 x 267 = 1602
# 7 x 267 = 1869
# 8 x 267 = 2136
# 9 x 267 = 2403
# 10 x 267 = 2670
#
# 1 x 268 = 268
# 2 x 268 = 536
# 3 x 268 = 804
# 4 x 268 = 1072
# 5 x 268 = 1340
# 6 x 268 = 1608
# 7 x 268 = 1876
# 8 x 268 = 2144
# 9 x 268 = 2412
# 10 x 268 = 2680
#
# 1 x 269 = 269
# 2 x 269 = 538
# 3 x 269 = 807
# 4 x 269 = 1076
# 5 x 269 = 1345
# 6 x 269 = 1614
# 7 x 269 = 1883
# 8 x 269 = 2152
# 9 x 269 = 2421
# 10 x 269 = 2690
#
# 1 x 270 = 270
# 2 x 270 = 540
# 3 x 270 = 810
# 4 x 270 = 1080
# 5 x 270 = 1350
# 6 x 270 = 1620
# 7 x 270 = 1890
# 8 x 270 = 2160
# 9 x 270 = 2430
# 10 x 270 = 2700
#
# 1 x 271 = 271
# 2 x 271 = 542
# 3 x 271 = 813
# 4 x 271 = 1084
# 5 x 271 = 1355
# 6 x 271 = 1626
# 7 x 271 = 1897
# 8 x 271 = 2168
# 9 x 271 = 2439
# 10 x 271 = 2710
#
# 1 x 272 = 272
# 2 x 272 = 544
# 3 x 272 = 816
# 4 x 272 = 1088
# 5 x 272 = 1360
# 6 x 272 = 1632
# 7 x 272 = 1904
# 8 x 272 = 2176
# 9 x 272 = 2448
# 10 x 272 = 2720
#
# 1 x 273 = 273
# 2 x 273 = 546
# 3 x 273 = 819
# 4 x 273 = 1092
# 5 x 273 = 1365
# 6 x 273 = 1638
# 7 x 273 = 1911
# 8 x 273 = 2184
# 9 x 273 = 2457
# 10 x 273 = 2730
#
# 1 x 274 = 274
# 2 x 274 = 548
# 3 x 274 = 822
# 4 x 274 = 1096
# 5 x 274 = 1370
# 6 x 274 = 1644
# 7 x 274 = 1918
# 8 x 274 = 2192
# 9 x 274 = 2466
# 10 x 274 = 2740
#
# 1 x 275 = 275
# 2 x 275 = 550
# 3 x 275 = 825
# 4 x 275 = 1100
# 5 x 275 = 1375
# 6 x 275 = 1650
# 7 x 275 = 1925
# 8 x 275 = 2200
# 9 x 275 = 2475
# 10 x 275 = 2750
#
# 1 x 276 = 276
# 2 x 276 = 552
# 3 x 276 = 828
# 4 x 276 = 1104
# 5 x 276 = 1380
# 6 x 276 = 1656
# 7 x 276 = 1932
# 8 x 276 = 2208
# 9 x 276 = 2484
# 10 x 276 = 2760
#
# 1 x 277 = 277
# 2 x 277 = 554
# 3 x 277 = 831
# 4 x 277 = 1108
# 5 x 277 = 1385
# 6 x 277 = 1662
# 7 x 277 = 1939
# 8 x 277 = 2216
# 9 x 277 = 2493
# 10 x 277 = 2770
#
# 1 x 278 = 278
# 2 x 278 = 556
# 3 x 278 = 834
# 4 x 278 = 1112
# 5 x 278 = 1390
# 6 x 278 = 1668
# 7 x 278 = 1946
# 8 x 278 = 2224
# 9 x 278 = 2502
# 10 x 278 = 2780
#
# 1 x 279 = 279
# 2 x 279 = 558
# 3 x 279 = 837
# 4 x 279 = 1116
# 5 x 279 = 1395
# 6 x 279 = 1674
# 7 x 279 = 1953
# 8 x 279 = 2232
# 9 x 279 = 2511
# 10 x 279 = 2790
#
# 1 x 280 = 280
# 2 x 280 = 560
# 3 x 280 = 840
# 4 x 280 = 1120
# 5 x 280 = 1400
# 6 x 280 = 1680
# 7 x 280 = 1960
# 8 x 280 = 2240
# 9 x 280 = 2520
# 10 x 280 = 2800
#
# 1 x 281 = 281
# 2 x 281 = 562
# 3 x 281 = 843
# 4 x 281 = 1124
# 5 x 281 = 1405
# 6 x 281 = 1686
# 7 x 281 = 1967
# 8 x 281 = 2248
# 9 x 281 = 2529
# 10 x 281 = 2810
#
# 1 x 282 = 282
# 2 x 282 = 564
# 3 x 282 = 846
# 4 x 282 = 1128
# 5 x 282 = 1410
# 6 x 282 = 1692
# 7 x 282 = 1974
# 8 x 282 = 2256
# 9 x 282 = 2538
# 10 x 282 = 2820
#
# 1 x 283 = 283
# 2 x 283 = 566
# 3 x 283 = 849
# 4 x 283 = 1132
# 5 x 283 = 1415
# 6 x 283 = 1698
# 7 x 283 = 1981
# 8 x 283 = 2264
# 9 x 283 = 2547
# 10 x 283 = 2830
#
# 1 x 284 = 284
# 2 x 284 = 568
# 3 x 284 = 852
# 4 x 284 = 1136
# 5 x 284 = 1420
# 6 x 284 = 1704
# 7 x 284 = 1988
# 8 x 284 = 2272
# 9 x 284 = 2556
# 3 x 320 = 960
# 4 x 320 = 1280
# 5 x 320 = 1600
# 6 x 320 = 1920
# 7 x 320 = 2240
# 8 x 320 = 2560
# 9 x 320 = 2880
# 10 x 320 = 3200
#
# 1 x 321 = 321
# 2 x 321 = 642
# 3 x 321 = 963
# 4 x 321 = 1284
# 5 x 321 = 1605
# 6 x 321 = 1926
# 7 x 321 = 2247
# 8 x 321 = 2568
# 9 x 321 = 2889
# 10 x 321 = 3210
#
# 1 x 322 = 322
# 2 x 322 = 644
# 3 x 322 = 966
# 4 x 322 = 1288
# 5 x 322 = 1610
# 6 x 322 = 1932
# 7 x 322 = 2254
# 8 x 322 = 2576
# 9 x 322 = 2898
# 10 x 322 = 3220
#
# 1 x 323 = 323
# 2 x 323 = 646
# 3 x 323 = 969
# 4 x 323 = 1292
# 5 x 323 = 1615
# 6 x 323 = 1938
# 7 x 323 = 2261
# 8 x 323 = 2584
# 9 x 323 = 2907
# 10 x 323 = 3230
#
# 1 x 324 = 324
# 2 x 324 = 648
# 3 x 324 = 972
# 4 x 324 = 1296
# 5 x 324 = 1620
# 6 x 324 = 1944
# 7 x 324 = 2268
# 8 x 324 = 2592
# 9 x 324 = 2916
# 10 x 324 = 3240
#
# 1 x 325 = 325
# 2 x 325 = 650
# 3 x 325 = 975
# 4 x 325 = 1300
# 5 x 325 = 1625
# 6 x 325 = 1950
# 7 x 325 = 2275
# 8 x 325 = 2600
# 9 x 325 = 2925
# 10 x 325 = 3250
#
# 1 x 326 = 326
# 2 x 326 = 652
# 3 x 326 = 978
# 4 x 326 = 1304
# 5 x 326 = 1630
# 6 x 326 = 1956
# 7 x 326 = 2282
# 8 x 326 = 2608
# 9 x 326 = 2934
# 10 x 326 = 3260
#
# 1 x 327 = 327
# 2 x 327 = 654
# 3 x 327 = 981
# 4 x 327 = 1308
# 5 x 327 = 1635
# 6 x 327 = 1962
# 7 x 327 = 2289
# 8 x 327 = 2616
# 9 x 327 = 2943
# 10 x 327 = 3270
#
# 1 x 328 = 328
# 2 x 328 = 656
# 3 x 328 = 984
# 4 x 328 = 1312
# 5 x 328 = 1640
# 6 x 328 = 1968
# 7 x 328 = 2296
# 8 x 328 = 2624
# 9 x 328 = 2952
# 10 x 328 = 3280
#
# 1 x 329 = 329
# 2 x 329 = 658
# 3 x 329 = 987
# 4 x 329 = 1316
# 5 x 329 = 1645
# 6 x 329 = 1974
# 7 x 329 = 2303
# 8 x 329 = 2632
# 9 x 329 = 2961
# 10 x 329 = 3290
#
# 1 x 330 = 330
# 2 x 330 = 660
# 3 x 330 = 990
# 4 x 330 = 1320
# 5 x 330 = 1650
# 6 x 330 = 1980
# 7 x 330 = 2310
# 8 x 330 = 2640
# 9 x 330 = 2970
# 10 x 330 = 3300
#
# 1 x 331 = 331
# 2 x 331 = 662
# 3 x 331 = 993
# 4 x 331 = 1324
# 5 x 331 = 1655
# 6 x 331 = 1986
# 7 x 331 = 2317
# 8 x 331 = 2648
# 9 x 331 = 2979
# 10 x 331 = 3310
#
# 2 x 1141 = 2282
# 3 x 1141 = 3423
# 4 x 1141 = 4564
# 5 x 1141 = 5705
# 6 x 1141 = 6846
# 7 x 1141 = 7987
# 8 x 1141 = 9128
# 9 x 1141 = 10269
# 10 x 1141 = 11410
#
# 1 x 1142 = 1142
# 2 x 1142 = 2284
# 3 x 1142 = 3426
# 4 x 1142 = 4568
# 5 x 1142 = 5710
# 6 x 1142 = 6852
# 7 x 1142 = 7994
# 8 x 1142 = 9136
# 9 x 1142 = 10278
# 10 x 1142 = 11420
#
# 1 x 1143 = 1143
# 2 x 1143 = 2286
# 3 x 1143 = 3429
# 4 x 1143 = 4572
# 5 x 1143 = 5715
# 6 x 1143 = 6858
# 7 x 1143 = 8001
# 8 x 1143 = 9144
# 9 x 1143 = 10287
# 10 x 1143 = 11430
#
# 1 x 1144 = 1144
# 2 x 1144 = 2288
# 3 x 1144 = 3432
# 4 x 1144 = 4576
# 5 x 1144 = 5720
# 6 x 1144 = 6864
# 7 x 1144 = 8008
# 8 x 1144 = 9152
# 9 x 1144 = 10296
# 10 x 1144 = 11440
#
# 1 x 1145 = 1145
# 2 x 1145 = 2290
# 3 x 1145 = 3435
# 4 x 1145 = 4580
# 5 x 1145 = 5725
# 6 x 1145 = 6870
# 7 x 1145 = 8015
# 8 x 1145 = 9160
# 9 x 1145 = 10305
# 10 x 1145 = 11450
#
# 1 x 1146 = 1146
# 2 x 1146 = 2292
# 3 x 1146 = 3438
# 4 x 1146 = 4584
# 5 x 1146 = 5730
# 6 x 1146 = 6876
# 7 x 1146 = 8022
# 8 x 1146 = 9168
# 9 x 1146 = 10314
# 10 x 1146 = 11460
#
# 1 x 1147 = 1147
# 2 x 1147 = 2294
# 3 x 1147 = 3441
# 4 x 1147 = 4588
# 5 x 1147 = 5735
# 6 x 1147 = 6882
# 7 x 1147 = 8029
# 8 x 1147 = 9176
# 9 x 1147 = 10323
# 10 x 1147 = 11470
#
# 1 x 1148 = 1148
# 2 x 1148 = 2296
# 3 x 1148 = 3444
# 4 x 1148 = 4592
# 5 x 1148 = 5740
# 6 x 1148 = 6888
# 7 x 1148 = 8036
# 8 x 1148 = 9184
# 9 x 1148 = 10332
# 10 x 1148 = 11480
#
# 1 x 1149 = 1149
# 2 x 1149 = 2298
# 3 x 1149 = 3447
# 4 x 1149 = 4596
# 5 x 1149 = 5745
# 6 x 1149 = 6894
# 7 x 1149 = 8043
# 8 x 1149 = 9192
# 9 x 1149 = 10341
# 10 x 1149 = 11490
#
# 1 x 1150 = 1150
# 2 x 1150 = 2300
# 3 x 1150 = 3450
# 4 x 1150 = 4600
# 5 x 1150 = 5750
# 6 x 1150 = 6900
# 7 x 1150 = 8050
# 8 x 1150 = 9200
# 9 x 1150 = 10350
# 10 x 1150 = 11500
#
# 1 x 1151 = 1151
# 2 x 1151 = 2302
# 3 x 1151 = 3453
# 4 x 1151 = 4604
# 5 x 1151 = 5755
# 6 x 1151 = 6906
# 7 x 1151 = 8057
# 8 x 1151 = 9208
# 9 x 1151 = 10359
# 10 x 1151 = 11510
#
# 1 x 1152 = 1152
# 2 x 1152 = 2304
# 3 x 1152 = 3456
# 4 x 1152 = 4608
# 5 x 1152 = 5760
# 6 x 1152 = 6912
# 7 x 1152 = 8064
# 8 x 1152 = 9216
# 9 x 1152 = 10368
# 10 x 1152 = 11520
#
# 1 x 1153 = 1153
# 2 x 1153 = 2306
# 3 x 1153 = 3459
# 4 x 1153 = 4612
# 5 x 1153 = 5765
# 6 x 1153 = 6918
# 7 x 1153 = 8071
# 8 x 1153 = 9224
# 9 x 1153 = 10377
# 10 x 1153 = 11530
#
# 1 x 1154 = 1154
# 2 x 1154 = 2308
# 3 x 1154 = 3462
# 4 x 1154 = 4616
# 5 x 1154 = 5770
# 6 x 1154 = 6924
# 7 x 1154 = 8078
# 8 x 1154 = 9232
# 9 x 1154 = 10386
# 10 x 1154 = 11540
#
# 1 x 1155 = 1155
# 2 x 1155 = 2310
# 3 x 1155 = 3465
# 4 x 1155 = 4620
# 5 x 1155 = 5775
# 6 x 1155 = 6930
# 7 x 1155 = 8085
# 8 x 1155 = 9240
# 9 x 1155 = 10395
# 10 x 1155 = 11550
#
# 1 x 1156 = 1156
# 2 x 1156 = 2312
# 3 x 1156 = 3468
# 4 x 1156 = 4624
# 5 x 1156 = 5780
# 6 x 1156 = 6936
# 7 x 1156 = 8092
# 8 x 1156 = 9248
# 9 x 1156 = 10404
# 10 x 1156 = 11560
#
# 1 x 1157 = 1157
# 2 x 1157 = 2314
# 3 x 1157 = 3471
# 4 x 1157 = 4628
# 5 x 1157 = 5785
# 6 x 1157 = 6942
# 7 x 1157 = 8099
# 8 x 1157 = 9256
# 9 x 1157 = 10413
# 10 x 1157 = 11570
#
# 1 x 1158 = 1158
# 2 x 1158 = 2316
# 3 x 1158 = 3474
# 4 x 1158 = 4632
# 5 x 1158 = 5790
# 6 x 1158 = 6948
# 7 x 1158 = 8106
# 8 x 1158 = 9264
# 9 x 1158 = 10422
# 10 x 1158 = 11580
#
# 1 x 1159 = 1159
# 2 x 1159 = 2318
# 3 x 1159 = 3477
# 4 x 1159 = 4636
# 5 x 1159 = 5795
# 6 x 1159 = 6954
# 7 x 1159 = 8113
# 8 x 1159 = 9272
# 9 x 1159 = 10431
# 10 x 1159 = 11590
#
# 1 x 1160 = 1160
# 2 x 1160 = 2320
# 3 x 1160 = 3480
# 4 x 1160 = 4640
# 5 x 1160 = 5800
# 6 x 1160 = 6960
# 7 x 1160 = 8120
# 8 x 1160 = 9280
# 9 x 1160 = 10440
# 10 x 1160 = 11600
#
# 1 x 1161 = 1161
# 2 x 1161 = 2322
# 3 x 1161 = 3483
# 4 x 1161 = 4644
# 5 x 1161 = 5805
# 6 x 1161 = 6966
# 7 x 1161 = 8127
# 8 x 1161 = 9288
# 9 x 1161 = 10449
# 10 x 1161 = 11610
#
# 1 x 1162 = 1162
# 2 x 1162 = 2324
# 3 x 1162 = 3486
# 4 x 1162 = 4648
# 5 x 1162 = 5810
# 6 x 1162 = 6972
# 7 x 1162 = 8134
# 8 x 1162 = 9296
# 9 x 1162 = 10458
# 10 x 1162 = 11620
#
# 1 x 1163 = 1163
# 2 x 1163 = 2326
# 3 x 1163 = 3489
# 4 x 1163 = 4652
# 5 x 1163 = 5815
# 6 x 1163 = 6978
# 7 x 1163 = 8141
# 8 x 1163 = 9304
# 9 x 1163 = 10467
# 10 x 1163 = 11630
#
# 1 x 1164 = 1164
# 2 x 1164 = 2328
# 3 x 1164 = 3492
# 4 x 1164 = 4656
# 5 x 1164 = 5820
# 6 x 1164 = 6984
# 7 x 1164 = 8148
# 8 x 1164 = 9312
# 9 x 1164 = 10476
# 10 x 1164 = 11640
#
# 1 x 1165 = 1165
# 2 x 1165 = 2330
# 3 x 1165 = 3495
# 4 x 1165 = 4660
# 5 x 1165 = 5825
# 6 x 1165 = 6990
# 7 x 1165 = 8155
# 8 x 1165 = 9320
# 9 x 1165 = 10485
# 10 x 1165 = 11650
#
# 1 x 1166 = 1166
# 2 x 1166 = 2332
# 3 x 1166 = 3498
# 4 x 1166 = 4664
# 5 x 1166 = 5830
# 6 x 1166 = 6996
# 7 x 1166 = 8162
# 8 x 1166 = 9328
# 9 x 1166 = 10494
# 10 x 1166 = 11660
#
# 1 x 1167 = 1167
# 2 x 1167 = 2334
# 3 x 1167 = 3501
# 4 x 1167 = 4668
# 5 x 1167 = 5835
# 6 x 1167 = 7002
# 7 x 1167 = 8169
# 8 x 1167 = 9336
# 9 x 1167 = 10503
# 10 x 1167 = 11670
#
# 1 x 1168 = 1168
# 2 x 1168 = 2336
# 3 x 1168 = 3504
# 4 x 1168 = 4672
# 5 x 1168 = 5840
# 6 x 1168 = 7008
# 7 x 1168 = 8176
# 8 x 1168 = 9344
# 9 x 1168 = 10512
# 10 x 1168 = 11680
#
# 1 x 1169 = 1169
# 2 x 1169 = 2338
# 3 x 1169 = 3507
# 4 x 1169 = 4676
# 5 x 1169 = 5845
# 6 x 1169 = 7014
# 7 x 1169 = 8183
# 8 x 1169 = 9352
# 9 x 1169 = 10521
# 10 x 1169 = 11690
#
# 1 x 1170 = 1170
# 2 x 1170 = 2340
# 3 x 1170 = 3510
# 4 x 1170 = 4680
# 5 x 1170 = 5850
# 6 x 1170 = 7020
# 7 x 1170 = 8190
# 8 x 1170 = 9360
# 9 x 1170 = 10530
# 10 x 1170 = 11700
#
# 1 x 1171 = 1171
# 2 x 1171 = 2342
# 3 x 1171 = 3513
# 4 x 1171 = 4684
# 5 x 1171 = 5855
# 6 x 1171 = 7026
# 7 x 1171 = 8197
# 8 x 1171 = 9368
# 9 x 1171 = 10539
# 10 x 1171 = 11710
#
# 1 x 1172 = 1172
# 2 x 1172 = 2344
# 3 x 1172 = 3516
# 4 x 1172 = 4688
# 5 x 1172 = 5860
# 6 x 1172 = 7032
# 7 x 1172 = 8204
# 8 x 1172 = 9376
# 9 x 1172 = 10548
# 10 x 1172 = 11720
#
# 1 x 1173 = 1173
# 2 x 1173 = 2346
# 3 x 1173 = 3519
# 8 x 1194 = 9552
# 9 x 1194 = 10746
# 10 x 1194 = 11940
#
# 1 x 1195 = 1195
# 2 x 1195 = 2390
# 3 x 1195 = 3585
# 4 x 1195 = 4780
# 5 x 1195 = 5975
# 6 x 1195 = 7170
# 7 x 1195 = 8365
# 8 x 1195 = 9560
# 9 x 1195 = 10755
# 10 x 1195 = 11950
#
# 1 x 1196 = 1196
# 2 x 1196 = 2392
# 3 x 1196 = 3588
# 4 x 1196 = 4784
# 5 x 1196 = 5980
# 6 x 1196 = 7176
# 7 x 1196 = 8372
# 8 x 1196 = 9568
# 9 x 1196 = 10764
# 10 x 1196 = 11960
#
# 1 x 1197 = 1197
# 2 x 1197 = 2394
# 3 x 1197 = 3591
# 4 x 1197 = 4788
# 5 x 1197 = 5985
# 6 x 1197 = 7182
# 7 x 1197 = 8379
# 8 x 1197 = 9576
# 9 x 1197 = 10773
# 10 x 1197 = 11970
#
# 1 x 1198 = 1198
# 2 x 1198 = 2396
# 3 x 1198 = 3594
# 4 x 1198 = 4792
# 5 x 1198 = 5990
# 6 x 1198 = 7188
# 7 x 1198 = 8386
# 8 x 1198 = 9584
# 9 x 1198 = 10782
# 10 x 1198 = 11980
#
# 1 x 1199 = 1199
# 2 x 1199 = 2398
# 3 x 1199 = 3597
# 4 x 1199 = 4796
# 5 x 1199 = 5995
# 6 x 1199 = 7194
# 7 x 1199 = 8393
# 8 x 1199 = 9592
# 9 x 1199 = 10791
# 10 x 1199 = 11990
#
# 1 x 1200 = 1200
# 2 x 1200 = 2400
# 3 x 1200 = 3600
# 4 x 1200 = 4800
# 5 x 1200 = 6000
# 6 x 1200 = 7200
# 7 x 1200 = 8400
# 8 x 1200 = 9600
# 9 x 1200 = 10800
# 10 x 1200 = 12000
#
# 1 x 1201 = 1201
# 2 x 1201 = 2402
# 3 x 1201 = 3603
# 4 x 1201 = 4804
# 5 x 1201 = 6005
# 6 x 1201 = 7206
# 7 x 1201 = 8407
# 8 x 1201 = 9608
# 9 x 1201 = 10809
# 10 x 1201 = 12010
#
# 1 x 1202 = 1202
# 2 x 1202 = 2404
# 3 x 1202 = 3606
# 4 x 1202 = 4808
# 5 x 1202 = 6010
# 6 x 1202 = 7212
# 7 x 1202 = 8414
# 8 x 1202 = 9616
# 9 x 1202 = 10818
# 10 x 1202 = 12020
#
# 1 x 1203 = 1203
# 2 x 1203 = 2406
# 3 x 1203 = 3609
# 4 x 1203 = 4812
# 5 x 1203 = 6015
# 6 x 1203 = 7218
# 7 x 1203 = 8421
# 8 x 1203 = 9624
# 9 x 1203 = 10827
# 10 x 1203 = 12030
#
# 1 x 1204 = 1204
# 2 x 1204 = 2408
# 3 x 1204 = 3612
# 4 x 1204 = 4816
# 5 x 1204 = 6020
# 6 x 1204 = 7224
# 7 x 1204 = 8428
# 8 x 1204 = 9632
# 9 x 1204 = 10836
# 10 x 1204 = 12040
#
# 1 x 1205 = 1205
# 2 x 1205 = 2410
# 3 x 1205 = 3615
# 4 x 1205 = 4820
# 5 x 1205 = 6025
# 6 x 1205 = 7230
# 7 x 1205 = 8435
# 8 x 1205 = 9640
# 9 x 1205 = 10845
# 10 x 1205 = 12050
#
# 1 x 1206 = 1206
# 2 x 1206 = 2412
# 3 x 1206 = 3618
# 4 x 1206 = 4824
# 5 x 1206 = 6030
# 6 x 1206 = 7236
# 7 x 1206 = 8442
# 8 x 1206 = 9648
# 9 x 1206 = 10854
# 10 x 1206 = 12060
#
# 1 x 1207 = 1207
# 2 x 1207 = 2414
# 3 x 1207 = 3621
# 4 x 1207 = 4828
# 5 x 1207 = 6035
# 6 x 1207 = 7242
# 7 x 1207 = 8449
# 8 x 1207 = 9656
# 9 x 1207 = 10863
# 10 x 1207 = 12070
#
# 1 x 1208 = 1208
# 2 x 1208 = 2416
# 3 x 1208 = 3624
# 4 x 1208 = 4832
# 5 x 1208 = 6040
# 6 x 1208 = 7248
# 7 x 1208 = 8456
# 8 x 1208 = 9664
# 9 x 1208 = 10872
# 10 x 1208 = 12080
#
# 1 x 1209 = 1209
# 2 x 1209 = 2418
# 3 x 1209 = 3627
# 4 x 1209 = 4836
# 5 x 1209 = 6045
# 6 x 1209 = 7254
# 7 x 1209 = 8463
# 8 x 1209 = 9672
# 9 x 1209 = 10881
# 10 x 1209 = 12090
#
# 1 x 1210 = 1210
# 2 x 1210 = 2420
# 3 x 1210 = 3630
# 4 x 1210 = 4840
# 5 x 1210 = 6050
# 6 x 1210 = 7260
# 7 x 1210 = 8470
# 8 x 1210 = 9680
# 9 x 1210 = 10890
# 10 x 1210 = 12100
#
# 1 x 1211 = 1211
# 2 x 1211 = 2422
# 3 x 1211 = 3633
# 4 x 1211 = 4844
# 5 x 1211 = 6055
# 6 x 1211 = 7266
# 7 x 1211 = 8477
# 8 x 1211 = 9688
# 9 x 1211 = 10899
# 10 x 1211 = 12110
#
# 1 x 1212 = 1212
# 2 x 1212 = 2424
# 3 x 1212 = 3636
# 4 x 1212 = 4848
# 5 x 1212 = 6060
# 6 x 1212 = 7272
# 7 x 1212 = 8484
# 8 x 1212 = 9696
# 9 x 1212 = 10908
# 10 x 1212 = 12120
#
# 1 x 1213 = 1213
# 2 x 1213 = 2426
# 3 x 1213 = 3639
# 4 x 1213 = 4852
# 5 x 1213 = 6065
# 6 x 1213 = 7278
# 7 x 1213 = 8491
# 8 x 1213 = 9704
# 9 x 1213 = 10917
# 10 x 1213 = 12130
#
# 1 x 1214 = 1214
# 2 x 1214 = 2428
# 3 x 1214 = 3642
# 4 x 1214 = 4856
# 5 x 1214 = 6070
# 6 x 1214 = 7284
# 7 x 1214 = 8498
# 8 x 1214 = 9712
# 9 x 1214 = 10926
# 10 x 1214 = 12140
#
# 1 x 1215 = 1215
# 2 x 1215 = 2430
# 3 x 1215 = 3645
# 4 x 1215 = 4860
# 5 x 1215 = 6075
# 6 x 1215 = 7290
# 7 x 1215 = 8505
# 8 x 1215 = 9720
# 9 x 1215 = 10935
# 10 x 1215 = 12150
#
# 1 x 1216 = 1216
# 2 x 1216 = 2432
# 3 x 1216 = 3648
# 4 x 1216 = 4864
# 5 x 1216 = 6080
# 6 x 1216 = 7296
# 7 x 1216 = 8512
# 8 x 1216 = 9728
# 9 x 1216 = 10944
# 10 x 1216 = 12160
#
# 1 x 1217 = 1217
# 2 x 1217 = 2434
# 3 x 1217 = 3651
# 4 x 1217 = 4868
# 5 x 1217 = 6085
# 6 x 1217 = 7302
# 7 x 1217 = 8519
# 8 x 1217 = 9736
# 9 x 1217 = 10953
# 10 x 1217 = 12170
#
# 1 x 1218 = 1218
# 2 x 1218 = 2436
# 3 x 1218 = 3654
# 4 x 1218 = 4872
# 5 x 1218 = 6090
# 6 x 1218 = 7308
# 7 x 1218 = 8526
# 8 x 1218 = 9744
# 9 x 1218 = 10962
# 10 x 1218 = 12180
#
# 1 x 1219 = 1219
# 2 x 1219 = 2438
# 3 x 1219 = 3657
# 4 x 1219 = 4876
# 5 x 1219 = 6095
# 6 x 1219 = 7314
# 7 x 1219 = 8533
# 8 x 1219 = 9752
# 9 x 1219 = 10971
# 10 x 1219 = 12190
#
# 1 x 1220 = 1220
# 2 x 1220 = 2440
# 3 x 1220 = 3660
# 4 x 1220 = 4880
# 5 x 1220 = 6100
# 6 x 1220 = 7320
# 7 x 1220 = 8540
# 8 x 1220 = 9760
# 9 x 1220 = 10980
# 10 x 1220 = 12200
#
# 1 x 1221 = 1221
# 2 x 1221 = 2442
# 3 x 1221 = 3663
# 4 x 1221 = 4884
# 5 x 1221 = 6105
# 6 x 1221 = 7326
# 7 x 1221 = 8547
# 8 x 1221 = 9768
# 9 x 1221 = 10989
# 10 x 1221 = 12210
#
# 1 x 1222 = 1222
# 2 x 1222 = 2444
# 3 x 1222 = 3666
# 4 x 1222 = 4888
# 5 x 1222 = 6110
# 6 x 1222 = 7332
# 7 x 1222 = 8554
# 8 x 1222 = 9776
# 9 x 1222 = 10998
# 10 x 1222 = 12220
#
# 1 x 1223 = 1223
# 2 x 1223 = 2446
# 3 x 1223 = 3669
# 4 x 1223 = 4892
# 5 x 1223 = 6115
# 6 x 1223 = 7338
# 7 x 1223 = 8561
# 8 x 1223 = 9784
# 9 x 1223 = 11007
# 10 x 1223 = 12230
#
# 1 x 1224 = 1224
# 2 x 1224 = 2448
# 3 x 1224 = 3672
# 4 x 1224 = 4896
# 5 x 1224 = 6120
# 6 x 1224 = 7344
# 7 x 1224 = 8568
# 8 x 1224 = 9792
# 9 x 1224 = 11016
# 10 x 1224 = 12240
#
# 1 x 1225 = 1225
# 2 x 1225 = 2450
# 3 x 1225 = 3675
# 4 x 1225 = 4900
# 5 x 1225 = 6125
# 6 x 1225 = 7350
# 7 x 1225 = 8575
# 8 x 1225 = 9800
# 9 x 1225 = 11025
# 10 x 1225 = 12250
#
# 1 x 1226 = 1226
# 2 x 1226 = 2452
# 3 x 1226 = 3678
# 4 x 1226 = 4904
# 5 x 1226 = 6130
# 6 x 1226 = 7356
# 7 x 1226 = 8582
# 8 x 1226 = 9808
# 9 x 1226 = 11034
# 10 x 1226 = 12260
#
# 1 x 1227 = 1227
# 2 x 1227 = 2454
# 3 x 1227 = 3681
# 4 x 1227 = 4908
# 5 x 1227 = 6135
# 6 x 1227 = 7362
# 7 x 1227 = 8589
# 8 x 1227 = 9816
# 9 x 1227 = 11043
# 10 x 1227 = 12270
#
# 1 x 1228 = 1228
# 2 x 1228 = 2456
# 3 x 1228 = 3684
# 4 x 1228 = 4912
# 5 x 1228 = 6140
# 6 x 1228 = 7368
# 7 x 1228 = 8596
# 8 x 1228 = 9824
# 9 x 1228 = 11052
# 10 x 1228 = 12280
#
# 1 x 1229 = 1229
# 2 x 1229 = 2458
# 3 x 1229 = 3687
# 4 x 1229 = 4916
# 5 x 1229 = 6145
# 6 x 1229 = 7374
# 7 x 1229 = 8603
# 8 x 1229 = 9832
# 9 x 1229 = 11061
# 10 x 1229 = 12290
#
# 1 x 1230 = 1230
# 2 x 1230 = 2460
# 3 x 1230 = 3690
# 4 x 1230 = 4920
# 5 x 1230 = 6150
# 6 x 1230 = 7380
# 7 x 1230 = 8610
# 8 x 1230 = 9840
# 9 x 1230 = 11070
# 10 x 1230 = 12300
#
# 1 x 1231 = 1231
# 2 x 1231 = 2462
# 3 x 1231 = 3693
# 4 x 1231 = 4924
# 5 x 1231 = 6155
# 6 x 1231 = 7386
# 7 x 1231 = 8617
# 8 x 1231 = 9848
# 9 x 1231 = 11079
# 10 x 1231 = 12310
#
# 1 x 1232 = 1232
# 2 x 1232 = 2464
# 3 x 1232 = 3696
# 4 x 1232 = 4928
# 5 x 1232 = 6160
# 6 x 1232 = 7392
# 7 x 1232 = 8624
# 8 x 1232 = 9856
# 9 x 1232 = 11088
# 10 x 1232 = 12320
#
# 1 x 1233 = 1233
# 2 x 1233 = 2466
# 3 x 1233 = 3699
# 4 x 1233 = 4932
# 5 x 1233 = 6165
# 6 x 1233 = 7398
# 7 x 1233 = 8631
# 8 x 1233 = 9864
# 9 x 1233 = 11097
# 10 x 1233 = 12330
#
# 1 x 1234 = 1234
# 2 x 1234 = 2468
# 3 x 1234 = 3702
# 4 x 1234 = 4936
# 5 x 1234 = 6170
# 6 x 1234 = 7404
# 7 x 1234 = 8638
# 8 x 1234 = 9872
# 9 x 1234 = 11106
# 10 x 1234 = 12340

# %% [markdown]
# ## For-loop

# %% [markdown]
# Vervang de while-loop door een werkende for-loop. De uitkomst van het programma mag daarbij niet veranderen.

# %%
def loopje():

    aantal = 0

    #while(aantal <= 10):
        #print(f"huidige getal: {aantal}")
        #aantal += 1
    
    
    # De rede warom 11 is: 
    # Omdat 11 zelf niet mee teld, dus gaat hij maar tot 10.
    # Hij begit ook automaties bij 0.
    for aantal in range(11):
        print(f"huidige getal: {aantal}")
        aantal += 1

loopje()
# Out:
# huidige getal: 0
# huidige getal: 1
# huidige getal: 2
# huidige getal: 3
# huidige getal: 4
# huidige getal: 5
# huidige getal: 6
# huidige getal: 7
# huidige getal: 8
# huidige getal: 9
# huidige getal: 10

# %% [markdown]
# Schrijf de methode checkEven die achtereenvolgens 12 getallen inleest en afdrukt hoe vaak het ingevoerde getal even was.

# %%
def checkEven():
    i = 0
    even = 0
    for i in range(12):
        x = int(input("Geef een getal: "))
        # Deze if controleerd of het even is
        if (x % 2 == 0):
            even += 1
        i += 1
    print(even)

checkEven()
# Out:
# 6

# %% [markdown]
# ## Objectoriëntatie

# %% [markdown]
# Maak een minisysteem voor een kledingwinkel. Maak verschillende klassen voor verschillende soorten kledingstukken, waarbij sommige klassen geërfd worden van andere klassen.
# - Maak een klasse Kledingstuk aan, waarin door de constructor een merk, een maat en een prijs geïnitialiseerd worden.
# - Maak een klasse Broek en een klasse Shirt, beide erven van de klasse Kledingstuk. Voeg aan Broek een broek_type, en aan Shirt een shirt_type toe (d.m.v. constructorgebruik).
# - Maak een klasse Spijkerbroek die erft van broek en een klasse Poloshirt die erft van shirt. Voeg aan Spijkerbroek een blauwtint toe, en aan Poloshirt een kraagsoort (d.m.v. constructorgebruik).
# - Implementeer in elke klasse een beschrijvingmethode, waarmee alle informatie over het betreffende kledingstuk wordt afgedrukt.
# - Maak van elke klasse een object aan en roep de beschrijvingmethode aan. Controleer nauwkeurig of alles naar behoren werkt.

# %%
class Kledingstuk:
    def __init__(self, merk, maat, prijs):
        self.merk = merk
        self.maat = maat
        self.prijs =prijs

    def beschrijving(self):
        print(f"Merk: {self.merk}")
        print(f"Maat: {self.maat}")
        print(f"Prijs: {self.prijs}")

class Broek(Kledingstuk):
    def __init__(self, merk, maat, prijs, broek_type):
        super().__init__(merk, maat, prijs)
        self.broek_type = broek_type

    def beschrijving(self):
        super().beschrijving()
        print(f"Broek type: {self.broek_type}")

class Shirt(Kledingstuk):
    def __init__(self, merk, maat, prijs, shirt_type):
        super().__init__(merk, maat, prijs)
        self.shirt_type = shirt_type

    def beschrijving(self):
        super().beschrijving()
        print(f"Shirt type: {self.shirt_type}")

class Spijkerbroek(Broek):
    def __init__(self, merk, maat, prijs, broek_type, blauwtint):
        super().__init__(merk, maat, prijs, broek_type)
        self.blauwtint = blauwtint

    def beschrijving(self):
        super().beschrijving()
        print(f"Blauwtint: {self.blauwtint}")

class Poloshirt(Shirt):
    def __init__(self, merk, maat, prijs, shirt_type, kraagsoort):
        super().__init__(merk, maat, prijs, shirt_type)
        self.kraagsoort = kraagsoort
    
    def beschrijving(self):
        super().beschrijving()
        print(f"Kraagsoort: {self.kraagsoort}")

# Aanmaken objecten en beschrijving roepen
kledingstuk = Kledingstuk("Nike", "M", 29.99)
broek = Broek("Levi's", "L", 79.99, "Chino")
shirt = Shirt("Adidas", "S", 34.99, "T-shirt")
spijkerbroek = Spijkerbroek("G-Star", "M", 99.99, "Slim fit", "Donkerblauw")
poloshirt = Poloshirt("Tommy Hilfiger", "L", 59.99, "Polo", "Button-down")

# Print is voor opmaak en verduidelijking
print("=== Kledingstuk ===")
kledingstuk.beschrijving()

print("\n=== Broek ===")
broek.beschrijving()

print("\n=== Shirt ===")
shirt.beschrijving()

print("\n=== Spijkerbroek ===")
spijkerbroek.beschrijving()

print("\n=== Poloshirt ===")
poloshirt.beschrijving()
# Out:
# === Kledingstuk ===
# Merk: Nike
# Maat: M
# Prijs: 29.99
#
# === Broek ===
# Merk: Levi's
# Maat: L
# Prijs: 79.99
# Broek type: Chino
#
# === Shirt ===
# Merk: Adidas
# Maat: S
# Prijs: 34.99
# Shirt type: T-shirt
#
# === Spijkerbroek ===
# Merk: G-Star
# Maat: M
# Prijs: 99.99
# Broek type: Slim fit
# Blauwtint: Donkerblauw
#
# === Poloshirt ===
# Merk: Tommy Hilfiger
# Maat: L
# Prijs: 59.99
# Shirt type: Polo
# Kraagsoort: Button-down

# %% [markdown]
# ## Verzamelingen

# %% [markdown]
# Kijk nu naar alle info onder het kopje *Verzamelingen* van de cheatsheet *Van Java naar Python - Cheatsheet*.

# %% [markdown]
# Initialiseer een lijst met de naam mijn_lijst met de volgende waarden:<br>
# Jelle, Marleen, Henk, Fatima, Jelle, Henk

# %%
Mijn_lijst = ["Jelle", "Marleen", "Henk", "Fatima", "Jelle", "Henk"]

for n in Mijn_lijst:
    print(n)
# Out:
# Jelle
# Marleen
# Henk
# Fatima
# Jelle
# Henk

# %% [markdown]
# Probeer nu de eerste waarde uit te lijst te veranderen in een naam naar keuze. Lukt dat?

# %%
Mijn_lijst[0] = "Anouk"
print(Mijn_lijst[0])
# Out:
# Anouk

# %% [markdown]
# Maak van bovengenoemde lijst nu een tupel, genaamd: mijn_tupel.

# %%
Mijn_tupel = ("Jelle", "Marleen", "Henk", "Fatima", "Jelle", "Henk")

for n in Mijn_tupel:
    print(n)
# Out:
# Jelle
# Marleen
# Henk
# Fatima
# Jelle
# Henk

# %% [markdown]
# Probeer nu de laatste waarde uit te tupel te veranderen in een naam naar keuze. Lukt dat?

# %%
# Tupel kan je niet aanpassen dus krijg je een error
Mijn_tupel[-1] = "Kim"
print(Mijn_tupel[-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Mijn_tupel[-1] = "Kim"
#       2 print(Mijn_tupel[-1])
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Initialiseer een dictionary met de volgende key-value-combinaties:
# - naam: "Jelle"
# - leeftijd: 30
# - beroep: "Docent"
# - hobby: "Volleybal"

# %% [markdown]
# Probeer nu de naam te veranderen naar een naam naar keuze. Lukt dat?

# %% [markdown]
# ## Data klaarzetten

# %% [markdown]
# Zet de volgende bestanden in een makkelijk terug te vinden map:
# - go_sales.sqlite
# - go_crm.sqlite
# - go_staff.sqlite

# %% [markdown]
# Bestudeer de bovenste 3 bestanden met DB Browser (SQLite) dat <a href="https://sqlitebrowser.org/dl/">hier</a> te downloaden is. Wat valt je op qua datatypen?<br>

# %% [markdown]
# ## Databasetabel inlezen

# %% [markdown]
# Creëer een databaseconnectie met het bestand go_sales.sqlite. Let op: deze staat in de map "data", die op zijn beurt in de hoofdmap staat. Tip: met `"../"` in `connect()` kun je naar de bovenliggende map gaan.

# %% [markdown]
# <b>Let goed op:</b><br>
# Als je per ongeluk een verkeerde bestandsnaam ingeeft, maakt Python zélf een leeg databasebestand aan! Er ontstaat dan dus een nieuwe .sqlite, en dat is nadrukkelijk <u>niet de bedoeling.</u>

# %% [markdown]
# Gebruik de onderstaande sql_query om te achterhalen welke databasetabellen in go_sales zitten.

# %%
sql_query = "SELECT name FROM sqlite_master WHERE type='table';"

#Vul dit codeblok verder in

# %% [markdown]
# Krijg je lege output? Dan heb je per ongeluk een leeg  databasebestand (.sqlite) aangemaakt.<br>
# Lees de informatie onder het kopje <b>Let goed op:</b> hierboven nog eens goed door.

# %% [markdown]
# Gebruik de gecreëerde databaseconnectie om de resultaten van de volgende query in een DataFrame te zetten:<br>
# *SELECT * FROM sales_staff*

# %% [markdown]
# ## Datumkolommen afhandelen

# %% [markdown]
# Zoals je misschien al hebt gezien in DB Browser, zijn datums als TEXT opgeslagen, en niet als DATE, DATETIME o.i.d. Hier moeten we dus nog even "typische datumkolommen" van maken. Dat doen we met de volgende code:

# %%
sales_staff['DATE_HIRED'] = pd.to_datetime(sales_staff['DATE_HIRED'])
sales_staff.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sales_staff['DATE_HIRED'] = pd.to_datetime(sales_staff['DATE_HIRED'])
#       2 sales_staff.dtypes
#
# NameError: name 'sales_staff' is not defined

# %% [markdown]
# Als we hier het jaar uit willen halen, schrijven we:

# %%
pd.DatetimeIndex(sales_staff['DATE_HIRED']).year

# %% [markdown]
# Deze zelfde syntax is te gebruiken voor het extraheren van kwartalen, maanden, weken en dagen. Probeer het maar eens!

# %% [markdown]
# ## DataFrames uitsplitsen en opbouwen met Series

# %% [markdown]
# De volgende 5 kolommen hebben betrekking op de contactdetails van elke medewerker in dit DataFrame:
# - SALES_STAFF_CODE
# - WORK_PHONE
# - EXTENSION
# - FAX
# - EMAIL
#
# Maak van elk van deze 5 kolommen een serie.

# %% [markdown]
# Zet allevijf gecreëerde series als kolommen naast elkaar in een DataFrame (*contact_details*). Gebruik pd.concat(...)<br>
# Hulpvraag: welke waarde geef je aan de axis-parameter?

# %% [markdown]
# ## Series en DataFrames maken vanuit lists en dictionaries

# %% [markdown]
# Met .head(*getal*) kan je de bovenste *getal* rijen van een tabel selecteren.<br>
# Selecteer op deze manier de bovenste 5 rijen van *contact_details*.<br>
# Sla dit resultaat op in een nieuw DataFrame.

# %% [markdown]
# Aan deze 10 rijen met contactdetails willen we 3 kolommen toevoegen: 'FIRST_LANGUAGE', 'SECOND_LANGUAGE' & 'THIRD_LANGUAGE'.<br>
# Iedereens 'First Language' is Engels, afgekort 'EN'. Maak een lijst waarin 5x 'EN' staat.<br>
# Converteer deze lijst vervolgens naar een serie en voeg deze horizontaal samen met het resultaat van de vorige opdracht.<br>
# Vergeet niet een passende naam te geven aan de nieuw ontstane kolom.

# %% [markdown]
# Maak nu de tweede kolom ('SECOND_LANGUAGE'). Maak daarvoor een dictionary, met daarin...
# - Als keys: alle indexen uit het resultaat van het vorige codeblok.
# - Als values: bij de eerste 3 elementen 'FR' (Frankrijk), bij de laatste 2 'DE' (Duitsland).
#
# Maak vervolgens ook hier weer een serie van en voeg ook deze weer horizontaal samen met het rsultaat van de vorige opdracht.<br>
# Vergeet niet een passende naam te geven aan de nieuw ontstane kolom.

# %% [markdown]
# Maak ten slotte de derde kolom ('THIRD_LANGUAGE') door een dictionary te maken met daarin...
# - Als key: de naam van de nieuwe kolom. Zie je het verschil qua keys met de vorige opdracht?
# - Als waarde: een lijst met daarin 'NL', 'NL', 'JPN', 'JPN', 'KOR'.
#
# Converteer deze dictionary nu naar een DataFrame en voeg deze horizontaal samen met het resultaat van de vorige opdracht.<br>
# Waarom hoef je hierna de nieuw ontstane kolom geen passende naam meer te geven?

# %% [markdown]
# ## Data toevoegen

# %% [markdown]
# ### Rijen

# %% [markdown]
# Gebruik de originele databasetabel *sales_staff*.<br>
# Voeg een extra rij toe met eigen invulling. Zorg ervoor dat de index netjes doorloopt.<br>
# Hulpvraag: welke waarde geef je nu aan axis?

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Voeg een kolom *FULL_NAME* toe die de waarden van *FIRST_NAME* en *LAST_NAME* achter elkaar zet, gescheiden door een spatie.

# %% [markdown]
# ## Data wijzigen

# %% [markdown]
# ### Datatypen

# %% [markdown]
# Door het attribuut .dtypes van een DataFrame op te vragen krijg je een serie die per kolom het datatype weergeeft. Doe dit bij de originele databasetabel *sales_staff*

# %% [markdown]
# Hier valt op dat elke kolom het datatype 'object' heeft: Python leest dus alles als string. Wiskundige operaties zijn hierdoor niet mogelijk.<br>
# We kunnen proberen om kolommen met getallen, bijvoorbeeld de 'extension', te converteren naar een int. Zie onderstaande code.

# %%
sales_staff['EXTENSION'] = sales_staff['EXTENSION'].astype(int)
sales_staff.dtypes

# %% [markdown]
# Dit lukt echter niet, omdat er in de kolom 'EXTENSION' lege waarden zitten die niet geconverteerd kunnen worden naar een int.<br>
# Wél kan je deze naar een float converteren, zie onderstaande code:

# %%
sales_staff['EXTENSION'] = sales_staff['EXTENSION'].astype(float)
sales_staff.dtypes

# %% [markdown]
# Als we in de rij van 'EXTENSION' kijken zien we dat de conversie van het datatype nu is gelukt.<br>
# Dit is <b>randvoorwaardelijk</b> voor het uitvoeren van wiskundige operaties.<br>

# %% [markdown]
# ### Rijen

# %% [markdown]
# Zorg er nu voor dat bij alle extensions 1 wordt opgeteld.

# %% [markdown]
# Elke 'Branch Manager' wordt nu 'General Manager'. Schrijf code zodat deze wijziging doorgevoerd wordt in het DataFrame.

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Verander de kolomnaam 'POSITION_EN' naar 'POSITION'.

# %% [markdown]
# ## Data verwijderen

# %% [markdown]
# ### Rijen

# %% [markdown]
# De medewerkers op indexen 98, 99 en 100 hebben helaas ontslag genomen.<br>
# Verwijder de bijbehorende rijen uit het DataFrame. Gebruik slechts één keer de .drop()-methode.

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Faxen zijn inmiddels ouderwets: niemand gebruikt zijn/haar faxnummer nog.<br>
# Verwijder de bijbehorende kolom uit het DataFrame.
